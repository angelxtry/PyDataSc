# %% [markdown]
# # ch04 데이터의 부분 집합 선택
#
# - Series나 DataFrame 데이터의 각 차원은 index 객체에 의해 레이블되어 있다.
# - 바로 이 index가 pandas의 데이터 구조가 Numpy의 n차원 배열과 구분되는 점이다.
# - index는 데이터의 row와 col에 의미 있는 레이블을 제공하고 pandas 사용자는 이 레이블을 사용해 데이터를 선택할 수 있다.
# - pandas는 row와 col의 위치를 정수로 지정해 데이터를 선택할 수 있게 해준다.
# - 이러한 이중적인 기능은 강력한 기능이지만, 데이터의 부분 집합을 선택할 때 다소 문법 상의 혼동을 일으키기도 한다.

# %%
import numpy as np
import pandas as pd
from pandas import DataFrame, Series

# %% [markdown]
# ## 1. Series 데이터 선택

# %% [markdown]
# - Series와 DataFrame은 indexing operator가 다수의 속성을 사용해 서로 다른 방식으로 데이터를 선택할 수 있게 할 수 있는 기능을 가진 복잡한 데이터 저장소다.
# - indexing operator 외에도 .iloc와 .loc 속성이 제공된다.
# - 이런 속성을 모두 합쳐 indexers라고 부른다.
# - s[itme]: indexing operator
# - s.loc[item]: .loc indexer

# %% [markdown]
# - .iloc indexer는 정수 위치만을 사용하여 선택하며 파이썬의 list와 비슷하게 작동한다.
# - .loc indexer는 레이블만을 통해 선택하고 파이썬의 딕셔너리와 비슷하게 작동한다.

# %% [markdown]
# - 대학 데이터셋을 학교 이름을 index로 읽어 들이고 indexing operator를 사용해 단일 col Series로 만든다.

# %%
college = pd.read_csv('../data/college.csv', index_col='INSTNM')

# %%
city = college['CITY']

# %%
city.head()
# Out:
# INSTNM
# Alabama A & M University                   Normal
# University of Alabama at Birmingham    Birmingham
# Amridge University                     Montgomery
# University of Alabama in Huntsville    Huntsville
# Alabama State University               Montgomery
# Name: CITY, dtype: object

# %% [markdown]
# - .iloc indexer는 오직 정수 위치로만 데이터를 선택할 수 있다.
# - 정수를 전달하면 스칼라 값을 반환한다.

# %%
city.iloc[3]
# Out:
# 'Huntsville'

# %% [markdown]
# - 여러 개의 정수를 list로 만들어 .iloc에 전달하면 Series를 반환한다.

# %%
city.iloc[[3, 4, 5]]
# Out:
# INSTNM
# University of Alabama in Huntsville    Huntsville
# Alabama State University               Montgomery
# The University of Alabama              Tuscaloosa
# Name: CITY, dtype: object

# %% [markdown]
# - 슬라이스 표기 방식을 이용하면 동일한 간격으로 데이터를 선택할 수 있다.

# %%
city.iloc[4:50:10]
# Out:
# INSTNM
# Alabama State University              Montgomery
# Enterprise State Community College    Enterprise
# Heritage Christian University           Florence
# Marion Military Institute                 Marion
# Reid State Technical College           Evergreen
# Name: CITY, dtype: object

# %% [markdown]
# - .loc indexer는 오직 레이블로만 선택한다.
# - 단일 레이블을 전달하면 스칼라 값을 반환한다.

# %%
city.loc['Heritage Christian University']
# Out:
# 'Florence'

# %% [markdown]
# - .iloc와 마찬가지로 레이블을 list로 만들어서 .loc에 전달하면 Series를 반환한다.

# %%
np.random.seed(1)

# %%
labels = list(np.random.choice(city.index, 4))

# %%
labels
# Out:
# ['Northwest HVAC/R Training Center',
#  'California State University-Dominguez Hills',
#  'Lower Columbia College',
#  'Southwest Acupuncture College-Boulder']

# %%
city.loc[labels]
# Out:
# INSTNM
# Northwest HVAC/R Training Center                Spokane
# California State University-Dominguez Hills      Carson
# Lower Columbia College                         Longview
# Southwest Acupuncture College-Boulder           Boulder
# Name: CITY, dtype: object

# %% [markdown]
# - .loc indexer도 슬라이스 표현을 사용할 수 있다.
# - 시작, 끝 값이 문자열이라는 것에 주의하자.

# %%
city.loc['Alabama State University':
         'Reid State Technical College': 10]
# Out:
# INSTNM
# Alabama State University              Montgomery
# Enterprise State Community College    Enterprise
# Heritage Christian University           Florence
# Marion Military Institute                 Marion
# Reid State Technical College           Evergreen
# Name: CITY, dtype: object

# %% [markdown]
# - 단일 원소를 선탁하고 그 결과를 Series에 보관하려면 스칼라 값을 전달하는 대신 단일 원소를 가진 list를 전달하면 된다.

# %% [markdown]
# ## 2. DataFrame row 선택

# %% [markdown]
# - DataFrame의 row를 선택할 때 가장 선호되고 명시적인 방법은 .iloc, .loc indexer를 사용하는 것이다.

# %% [markdown]
# - 대학 데이터셋을 읽어 들이고 학교 이름을 index로 설정한다.

# %%
college = pd.read_csv('../data/college.csv', index_col='INSTNM')

# %%
college.head()
# Out:
#                                            CITY STABBR  HBCU  MENONLY  \
# INSTNM
# Alabama A & M University                 Normal     AL   1.0      0.0
# University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
# Amridge University                   Montgomery     AL   0.0      0.0
# University of Alabama in Huntsville  Huntsville     AL   0.0      0.0
# Alabama State University             Montgomery     AL   1.0      0.0
#
#                                      WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# INSTNM
# Alabama A & M University                   0.0         0     424.0     420.0
# University of Alabama at Birmingham        0.0         0     570.0     565.0
# Amridge University                         0.0         1       NaN       NaN
# University of Alabama in Huntsville        0.0         0     595.0     590.0
# Alabama State University                   0.0         0     425.0     430.0
#
#                                      DISTANCEONLY     UGDS  \
# INSTNM
# Alabama A & M University                      0.0   4206.0
# University of Alabama at Birmingham           0.0  11383.0
# Amridge University                            1.0    291.0
# University of Alabama in Huntsville           0.0   5451.0
# Alabama State University                      0.0   4811.0
#
#                                             ...          UGDS_2MOR  UGDS_NRA  \
# INSTNM                                      ...
# Alabama A & M University                    ...             0.0000    0.0059
# University of Alabama at Birmingham         ...             0.0368    0.0179
# Amridge University                          ...             0.0000    0.0000
# University of Alabama in Huntsville         ...             0.0172    0.0332
# Alabama State University                    ...             0.0098    0.0243
#
#                                      UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  \
# INSTNM
# Alabama A & M University                0.0138    0.0656         1   0.7356
# University of Alabama at Birmingham     0.0100    0.2607         1   0.3460
# Amridge University                      0.2715    0.4536         1   0.6801
# University of Alabama in Huntsville     0.0350    0.2146         1   0.3072
# Alabama State University                0.0137    0.0892         1   0.7347
#
#                                      PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# INSTNM
# Alabama A & M University               0.8284   0.1049            30300
# University of Alabama at Birmingham    0.5214   0.2422            39700
# Amridge University                     0.7795   0.8540            40100
# University of Alabama in Huntsville    0.4596   0.2640            45500
# Alabama State University               0.7554   0.1270            26600
#
#                                      GRAD_DEBT_MDN_SUPP
# INSTNM
# Alabama A & M University                          33888
# University of Alabama at Birmingham             21941.5
# Amridge University                                23370
# University of Alabama in Huntsville               24097
# Alabama State University                        33118.5
#
# [5 rows x 26 columns]

# %% [markdown]
# - .iloc indexer에 정수를 전달하면 그 위치에 있는 전체 row를 선택한다.

# %%
college.iloc[0]
# Out:
# CITY                  Normal
# STABBR                    AL
# HBCU                       1
# MENONLY                    0
# WOMENONLY                  0
# RELAFFIL                   0
# SATVRMID                 424
# SATMTMID                 420
# DISTANCEONLY               0
# UGDS                    4206
# UGDS_WHITE            0.0333
# UGDS_BLACK            0.9353
# UGDS_HISP             0.0055
# UGDS_ASIAN            0.0019
# UGDS_AIAN             0.0024
# UGDS_NHPI             0.0019
# UGDS_2MOR                  0
# UGDS_NRA              0.0059
# UGDS_UNKN             0.0138
# PPTUG_EF              0.0656
# CURROPER                   1
# PCTPELL               0.7356
# PCTFLOAN              0.8284
# UG25ABV               0.1049
# MD_EARN_WNE_P10        30300
# GRAD_DEBT_MDN_SUPP     33888
# Name: Alabama A & M University, dtype: object

# %% [markdown]
# - .loc indexer에 레이블 인덱스를 전달하면 동일한 값을 얻어올 수 있다.

# %%
college.loc['Alabama A & M University']
# Out:
# CITY                  Normal
# STABBR                    AL
# HBCU                       1
# MENONLY                    0
# WOMENONLY                  0
# RELAFFIL                   0
# SATVRMID                 424
# SATMTMID                 420
# DISTANCEONLY               0
# UGDS                    4206
# UGDS_WHITE            0.0333
# UGDS_BLACK            0.9353
# UGDS_HISP             0.0055
# UGDS_ASIAN            0.0019
# UGDS_AIAN             0.0024
# UGDS_NHPI             0.0019
# UGDS_2MOR                  0
# UGDS_NRA              0.0059
# UGDS_UNKN             0.0138
# PPTUG_EF              0.0656
# CURROPER                   1
# PCTPELL               0.7356
# PCTFLOAN              0.8284
# UG25ABV               0.1049
# MD_EARN_WNE_P10        30300
# GRAD_DEBT_MDN_SUPP     33888
# Name: Alabama A & M University, dtype: object

# %% [markdown]
# - 다수의 독립된 row를 선택하려면 iloc index에 정수로 구성된 list를 전달하면 된다.

# %%
college.iloc[[0, 1, 2, 0]]
# Out:
#                                            CITY STABBR  HBCU  MENONLY  \
# INSTNM
# Alabama A & M University                 Normal     AL   1.0      0.0
# University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
# Amridge University                   Montgomery     AL   0.0      0.0
# Alabama A & M University                 Normal     AL   1.0      0.0
#
#                                      WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# INSTNM
# Alabama A & M University                   0.0         0     424.0     420.0
# University of Alabama at Birmingham        0.0         0     570.0     565.0
# Amridge University                         0.0         1       NaN       NaN
# Alabama A & M University                   0.0         0     424.0     420.0
#
#                                      DISTANCEONLY     UGDS  \
# INSTNM
# Alabama A & M University                      0.0   4206.0
# University of Alabama at Birmingham           0.0  11383.0
# Amridge University                            1.0    291.0
# Alabama A & M University                      0.0   4206.0
#
#                                             ...          UGDS_2MOR  UGDS_NRA  \
# INSTNM                                      ...
# Alabama A & M University                    ...             0.0000    0.0059
# University of Alabama at Birmingham         ...             0.0368    0.0179
# Amridge University                          ...             0.0000    0.0000
# Alabama A & M University                    ...             0.0000    0.0059
#
#                                      UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  \
# INSTNM
# Alabama A & M University                0.0138    0.0656         1   0.7356
# University of Alabama at Birmingham     0.0100    0.2607         1   0.3460
# Amridge University                      0.2715    0.4536         1   0.6801
# Alabama A & M University                0.0138    0.0656         1   0.7356
#
#                                      PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# INSTNM
# Alabama A & M University               0.8284   0.1049            30300
# University of Alabama at Birmingham    0.5214   0.2422            39700
# Amridge University                     0.7795   0.8540            40100
# Alabama A & M University               0.8284   0.1049            30300
#
#                                      GRAD_DEBT_MDN_SUPP
# INSTNM
# Alabama A & M University                          33888
# University of Alabama at Birmingham             21941.5
# Amridge University                                23370
# Alabama A & M University                          33888
#
# [4 rows x 26 columns]

# %% [markdown]
# - .loc에 정확한 대학명을 레이블 list로 전달하면 해당 DataFrame을 복제할 수 있다.

# %%
np.random.seed(10)

# %%
np.random.randint(len(college.index), size=4)
# Out:
# array([1289, 7293, 4623, 1344])

# %%
labels = college.index[np.random.randint(len(college.index), size=4)]

# %%
labels
# Out:
# Index(['Greenville Technical College', 'Ivy Tech Community College-Richmond',
#        'Goshen College', 'Chillicothe Beauty Academy Inc'],
#       dtype='object', name='INSTNM')

# %%
college.loc[labels]
# Out:
#                                             CITY STABBR  HBCU  MENONLY  \
# INSTNM
# Greenville Technical College          Greenville     SC   0.0      0.0
# Ivy Tech Community College-Richmond     Richmond     IN   NaN      NaN
# Goshen College                            Goshen     IN   0.0      0.0
# Chillicothe Beauty Academy Inc       Chillicothe     MO   0.0      0.0
#
#                                      WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# INSTNM
# Greenville Technical College               0.0         0       NaN       NaN
# Ivy Tech Community College-Richmond        NaN         1       NaN       NaN
# Goshen College                             0.0         1     548.0     553.0
# Chillicothe Beauty Academy Inc             0.0         0       NaN       NaN
#
#                                      DISTANCEONLY     UGDS  \
# INSTNM
# Greenville Technical College                  0.0  11186.0
# Ivy Tech Community College-Richmond           NaN      NaN
# Goshen College                                0.0    746.0
# Chillicothe Beauty Academy Inc                0.0     15.0
#
#                                             ...          UGDS_2MOR  UGDS_NRA  \
# INSTNM                                      ...
# Greenville Technical College                ...             0.0224    0.0023
# Ivy Tech Community College-Richmond         ...                NaN       NaN
# Goshen College                              ...             0.0335    0.0952
# Chillicothe Beauty Academy Inc              ...             0.0000    0.0000
#
#                                      UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  \
# INSTNM
# Greenville Technical College            0.0427    0.5681         1   0.6139
# Ivy Tech Community College-Richmond        NaN       NaN         1      NaN
# Goshen College                          0.0067    0.0603         1   0.3080
# Chillicothe Beauty Academy Inc          0.0000    0.0000         1   0.4138
#
#                                      PCTFLOAN  UG25ABV    MD_EARN_WNE_P10  \
# INSTNM
# Greenville Technical College           0.4705   0.4130              30000
# Ivy Tech Community College-Richmond       NaN      NaN              29400
# Goshen College                         0.5990   0.1232              37800
# Chillicothe Beauty Academy Inc         0.2069   0.0000  PrivacySuppressed
#
#                                      GRAD_DEBT_MDN_SUPP
# INSTNM
# Greenville Technical College                      18715
# Ivy Tech Community College-Richmond               13000
# Goshen College                                    20671
# Chillicothe Beauty Academy Inc        PrivacySuppressed
#
# [4 rows x 26 columns]

# %% [markdown]
# - .iloc, .loc 모두 슬라이스 표기를 사용할 수 있다.

# %%
college.iloc[0:2]
# Out:
#                                            CITY STABBR  HBCU  MENONLY  \
# INSTNM
# Alabama A & M University                 Normal     AL   1.0      0.0
# University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
#
#                                      WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# INSTNM
# Alabama A & M University                   0.0         0     424.0     420.0
# University of Alabama at Birmingham        0.0         0     570.0     565.0
#
#                                      DISTANCEONLY     UGDS  \
# INSTNM
# Alabama A & M University                      0.0   4206.0
# University of Alabama at Birmingham           0.0  11383.0
#
#                                             ...          UGDS_2MOR  UGDS_NRA  \
# INSTNM                                      ...
# Alabama A & M University                    ...             0.0000    0.0059
# University of Alabama at Birmingham         ...             0.0368    0.0179
#
#                                      UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  \
# INSTNM
# Alabama A & M University                0.0138    0.0656         1   0.7356
# University of Alabama at Birmingham     0.0100    0.2607         1   0.3460
#
#                                      PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# INSTNM
# Alabama A & M University               0.8284   0.1049            30300
# University of Alabama at Birmingham    0.5214   0.2422            39700
#
#                                      GRAD_DEBT_MDN_SUPP
# INSTNM
# Alabama A & M University                          33888
# University of Alabama at Birmingham             21941.5
#
# [2 rows x 26 columns]

# %%
start = 'Alabama A & M University'
stop = 'University of Alabama at Birmingham'
college.loc[start:stop]
# Out:
#                                            CITY STABBR  HBCU  MENONLY  \
# INSTNM
# Alabama A & M University                 Normal     AL   1.0      0.0
# University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
#
#                                      WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# INSTNM
# Alabama A & M University                   0.0         0     424.0     420.0
# University of Alabama at Birmingham        0.0         0     570.0     565.0
#
#                                      DISTANCEONLY     UGDS  \
# INSTNM
# Alabama A & M University                      0.0   4206.0
# University of Alabama at Birmingham           0.0  11383.0
#
#                                             ...          UGDS_2MOR  UGDS_NRA  \
# INSTNM                                      ...
# Alabama A & M University                    ...             0.0000    0.0059
# University of Alabama at Birmingham         ...             0.0368    0.0179
#
#                                      UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  \
# INSTNM
# Alabama A & M University                0.0138    0.0656         1   0.7356
# University of Alabama at Birmingham     0.0100    0.2607         1   0.3460
#
#                                      PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# INSTNM
# Alabama A & M University               0.8284   0.1049            30300
# University of Alabama at Birmingham    0.5214   0.2422            39700
#
#                                      GRAD_DEBT_MDN_SUPP
# INSTNM
# Alabama A & M University                          33888
# University of Alabama at Birmingham             21941.5
#
# [2 rows x 26 columns]

# %%
college.head()
# Out:
#                                            CITY STABBR  HBCU  MENONLY  \
# INSTNM
# Alabama A & M University                 Normal     AL   1.0      0.0
# University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
# Amridge University                   Montgomery     AL   0.0      0.0
# University of Alabama in Huntsville  Huntsville     AL   0.0      0.0
# Alabama State University             Montgomery     AL   1.0      0.0
#
#                                      WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# INSTNM
# Alabama A & M University                   0.0         0     424.0     420.0
# University of Alabama at Birmingham        0.0         0     570.0     565.0
# Amridge University                         0.0         1       NaN       NaN
# University of Alabama in Huntsville        0.0         0     595.0     590.0
# Alabama State University                   0.0         0     425.0     430.0
#
#                                      DISTANCEONLY     UGDS  \
# INSTNM
# Alabama A & M University                      0.0   4206.0
# University of Alabama at Birmingham           0.0  11383.0
# Amridge University                            1.0    291.0
# University of Alabama in Huntsville           0.0   5451.0
# Alabama State University                      0.0   4811.0
#
#                                             ...          UGDS_2MOR  UGDS_NRA  \
# INSTNM                                      ...
# Alabama A & M University                    ...             0.0000    0.0059
# University of Alabama at Birmingham         ...             0.0368    0.0179
# Amridge University                          ...             0.0000    0.0000
# University of Alabama in Huntsville         ...             0.0172    0.0332
# Alabama State University                    ...             0.0098    0.0243
#
#                                      UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  \
# INSTNM
# Alabama A & M University                0.0138    0.0656         1   0.7356
# University of Alabama at Birmingham     0.0100    0.2607         1   0.3460
# Amridge University                      0.2715    0.4536         1   0.6801
# University of Alabama in Huntsville     0.0350    0.2146         1   0.3072
# Alabama State University                0.0137    0.0892         1   0.7347
#
#                                      PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# INSTNM
# Alabama A & M University               0.8284   0.1049            30300
# University of Alabama at Birmingham    0.5214   0.2422            39700
# Amridge University                     0.7795   0.8540            40100
# University of Alabama in Huntsville    0.4596   0.2640            45500
# Alabama State University               0.7554   0.1270            26600
#
#                                      GRAD_DEBT_MDN_SUPP
# INSTNM
# Alabama A & M University                          33888
# University of Alabama at Birmingham             21941.5
# Amridge University                                23370
# University of Alabama in Huntsville               24097
# Alabama State University                        33118.5
#
# [5 rows x 26 columns]

# %% [markdown]
# - DataFrame에서 iloc로 row를 선택
# - index로 index label을 선택
# - tolist()로 list로 변환

# %%
college.iloc[[0, 1, 2]].index.tolist()
# Out:
# ['Alabama A & M University',
#  'University of Alabama at Birmingham',
#  'Amridge University']

# %% [markdown]
# ## 3. DataFrame row, col 동시에 선택
# ## 4. 정수와 레이블로 데이터 선택
# ## 5. 스칼라 선택 더 빠르게 하기
# ## 6. row를 게으르게 슬라이스
# ## 7. 사전 순서대로 슬라이스
