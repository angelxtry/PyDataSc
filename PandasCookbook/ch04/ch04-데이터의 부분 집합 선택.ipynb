# %% [markdown]
# # ch04 데이터의 부분 집합 선택
#
# - Series나 DataFrame 데이터의 각 차원은 index 객체에 의해 레이블되어 있다.
# - 바로 이 index가 pandas의 데이터 구조가 Numpy의 n차원 배열과 구분되는 점이다.
# - index는 데이터의 row와 col에 의미 있는 레이블을 제공하고 pandas 사용자는 이 레이블을 사용해 데이터를 선택할 수 있다.
# - pandas는 row와 col의 위치를 정수로 지정해 데이터를 선택할 수 있게 해준다.
# - 이러한 이중적인 기능은 강력한 기능이지만, 데이터의 부분 집합을 선택할 때 다소 문법 상의 혼동을 일으키기도 한다.

# %%
import numpy as np
import pandas as pd
from pandas import DataFrame, Series

# %% [markdown]
# ## 1. Series 데이터 선택

# %% [markdown]
# - Series와 DataFrame은 indexing operator가 다수의 속성을 사용해 서로 다른 방식으로 데이터를 선택할 수 있게 할 수 있는 기능을 가진 복잡한 데이터 저장소다.
# - indexing operator 외에도 .iloc와 .loc 속성이 제공된다.
# - 이런 속성을 모두 합쳐 indexers라고 부른다.
# - s[itme]: indexing operator
# - s.loc[item]: .loc indexer

# %% [markdown]
# - .iloc indexer는 정수 위치만을 사용하여 선택하며 파이썬의 list와 비슷하게 작동한다.
# - .loc indexer는 레이블만을 통해 선택하고 파이썬의 딕셔너리와 비슷하게 작동한다.

# %% [markdown]
# - 대학 데이터셋을 학교 이름을 index로 읽어 들이고 indexing operator를 사용해 단일 col Series로 만든다.

# %%
college = pd.read_csv('../data/college.csv', index_col='INSTNM')

# %%
city = college['CITY']

# %%
city.head()
# Out:
# INSTNM
# Alabama A & M University                   Normal
# University of Alabama at Birmingham    Birmingham
# Amridge University                     Montgomery
# University of Alabama in Huntsville    Huntsville
# Alabama State University               Montgomery
# Name: CITY, dtype: object

# %% [markdown]
# - .iloc indexer는 오직 정수 위치로만 데이터를 선택할 수 있다.
# - 정수를 전달하면 스칼라 값을 반환한다.

# %%
city.iloc[3]
# Out:
# 'Huntsville'

# %% [markdown]
# - 여러 개의 정수를 list로 만들어 .iloc에 전달하면 Series를 반환한다.

# %%
city.iloc[[3, 4, 5]]
# Out:
# INSTNM
# University of Alabama in Huntsville    Huntsville
# Alabama State University               Montgomery
# The University of Alabama              Tuscaloosa
# Name: CITY, dtype: object

# %% [markdown]
# - 슬라이스 표기 방식을 이용하면 동일한 간격으로 데이터를 선택할 수 있다.

# %%
city.iloc[4:50:10]
# Out:
# INSTNM
# Alabama State University              Montgomery
# Enterprise State Community College    Enterprise
# Heritage Christian University           Florence
# Marion Military Institute                 Marion
# Reid State Technical College           Evergreen
# Name: CITY, dtype: object

# %% [markdown]
# - .loc indexer는 오직 레이블로만 선택한다.
# - 단일 레이블을 전달하면 스칼라 값을 반환한다.

# %%
city.loc['Heritage Christian University']
# Out:
# 'Florence'

# %% [markdown]
# - .iloc와 마찬가지로 레이블을 list로 만들어서 .loc에 전달하면 Series를 반환한다.

# %%
np.random.seed(1)

# %%
labels = list(np.random.choice(city.index, 4))

# %%
labels
# Out:
# ['Northwest HVAC/R Training Center',
#  'California State University-Dominguez Hills',
#  'Lower Columbia College',
#  'Southwest Acupuncture College-Boulder']

# %%
city.loc[labels]
# Out:
# INSTNM
# Northwest HVAC/R Training Center                Spokane
# California State University-Dominguez Hills      Carson
# Lower Columbia College                         Longview
# Southwest Acupuncture College-Boulder           Boulder
# Name: CITY, dtype: object

# %% [markdown]
# - .loc indexer도 슬라이스 표현을 사용할 수 있다.
# - 시작, 끝 값이 문자열이라는 것에 주의하자.

# %%
city.loc['Alabama State University':
         'Reid State Technical College': 10]
# Out:
# INSTNM
# Alabama State University              Montgomery
# Enterprise State Community College    Enterprise
# Heritage Christian University           Florence
# Marion Military Institute                 Marion
# Reid State Technical College           Evergreen
# Name: CITY, dtype: object

# %% [markdown]
# - 단일 원소를 선탁하고 그 결과를 Series에 보관하려면 스칼라 값을 전달하는 대신 단일 원소를 가진 list를 전달하면 된다.

# %% [markdown]
# ## 2. DataFrame row 선택

# %% [markdown]
# - DataFrame의 row를 선택할 때 가장 선호되고 명시적인 방법은 .iloc, .loc indexer를 사용하는 것이다.

# %% [markdown]
# - 대학 데이터셋을 읽어 들이고 학교 이름을 index로 설정한다.

# %%
college = pd.read_csv('../data/college.csv', index_col='INSTNM')

# %%
college.head()
# Out:
#                                            CITY STABBR  HBCU  MENONLY  \
# INSTNM
# Alabama A & M University                 Normal     AL   1.0      0.0
# University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
# Amridge University                   Montgomery     AL   0.0      0.0
# University of Alabama in Huntsville  Huntsville     AL   0.0      0.0
# Alabama State University             Montgomery     AL   1.0      0.0
#
#                                      WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# INSTNM
# Alabama A & M University                   0.0         0     424.0     420.0
# University of Alabama at Birmingham        0.0         0     570.0     565.0
# Amridge University                         0.0         1       NaN       NaN
# University of Alabama in Huntsville        0.0         0     595.0     590.0
# Alabama State University                   0.0         0     425.0     430.0
#
#                                      DISTANCEONLY     UGDS  \
# ...

# %% [markdown]
# - .iloc indexer에 정수를 전달하면 그 위치에 있는 전체 row를 선택한다.

# %%
college.iloc[0]
# Out:
# CITY                  Normal
# STABBR                    AL
# HBCU                       1
# MENONLY                    0
# WOMENONLY                  0
# RELAFFIL                   0
# SATVRMID                 424
# SATMTMID                 420
# DISTANCEONLY               0
# UGDS                    4206
# UGDS_WHITE            0.0333
# UGDS_BLACK            0.9353
# UGDS_HISP             0.0055
# UGDS_ASIAN            0.0019
# UGDS_AIAN             0.0024
# UGDS_NHPI             0.0019
# UGDS_2MOR                  0
# UGDS_NRA              0.0059
# UGDS_UNKN             0.0138
# PPTUG_EF              0.0656
# CURROPER                   1
# PCTPELL               0.7356
# PCTFLOAN              0.8284
# UG25ABV               0.1049
# MD_EARN_WNE_P10        30300
# GRAD_DEBT_MDN_SUPP     33888
# Name: Alabama A & M University, dtype: object

# %% [markdown]
# - .loc indexer에 레이블 인덱스를 전달하면 동일한 값을 얻어올 수 있다.

# %%
college.loc['Alabama A & M University']
# Out:
# CITY                  Normal
# STABBR                    AL
# HBCU                       1
# MENONLY                    0
# WOMENONLY                  0
# RELAFFIL                   0
# SATVRMID                 424
# SATMTMID                 420
# DISTANCEONLY               0
# UGDS                    4206
# UGDS_WHITE            0.0333
# UGDS_BLACK            0.9353
# UGDS_HISP             0.0055
# UGDS_ASIAN            0.0019
# UGDS_AIAN             0.0024
# UGDS_NHPI             0.0019
# UGDS_2MOR                  0
# UGDS_NRA              0.0059
# UGDS_UNKN             0.0138
# PPTUG_EF              0.0656
# CURROPER                   1
# PCTPELL               0.7356
# PCTFLOAN              0.8284
# UG25ABV               0.1049
# MD_EARN_WNE_P10        30300
# GRAD_DEBT_MDN_SUPP     33888
# Name: Alabama A & M University, dtype: object

# %% [markdown]
# - 다수의 독립된 row를 선택하려면 iloc index에 정수로 구성된 list를 전달하면 된다.

# %%
college.iloc[[0, 1, 2, 0]]
# Out:
#                                            CITY STABBR  HBCU  MENONLY  \
# INSTNM
# Alabama A & M University                 Normal     AL   1.0      0.0
# University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
# Amridge University                   Montgomery     AL   0.0      0.0
# Alabama A & M University                 Normal     AL   1.0      0.0
#
#                                      WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# INSTNM
# Alabama A & M University                   0.0         0     424.0     420.0
# University of Alabama at Birmingham        0.0         0     570.0     565.0
# Amridge University                         0.0         1       NaN       NaN
# Alabama A & M University                   0.0         0     424.0     420.0
#
#                                      DISTANCEONLY     UGDS  \
# INSTNM
# Alabama A & M University                      0.0   4206.0
# University of Alabama at Birmingham           0.0  11383.0
# ...

# %% [markdown]
# - .loc에 정확한 대학명을 레이블 list로 전달하면 해당 DataFrame을 복제할 수 있다.

# %%
np.random.seed(10)

# %%
np.random.randint(len(college.index), size=4)
# Out:
# array([1289, 7293, 4623, 1344])

# %%
labels = college.index[np.random.randint(len(college.index), size=4)]

# %%
labels
# Out:
# Index(['Greenville Technical College', 'Ivy Tech Community College-Richmond',
#        'Goshen College', 'Chillicothe Beauty Academy Inc'],
#       dtype='object', name='INSTNM')

# %%
college.loc[labels]
# Out:
#                                             CITY STABBR  HBCU  MENONLY  \
# INSTNM
# Greenville Technical College          Greenville     SC   0.0      0.0
# Ivy Tech Community College-Richmond     Richmond     IN   NaN      NaN
# Goshen College                            Goshen     IN   0.0      0.0
# Chillicothe Beauty Academy Inc       Chillicothe     MO   0.0      0.0
#
#                                      WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# INSTNM
# Greenville Technical College               0.0         0       NaN       NaN
# Ivy Tech Community College-Richmond        NaN         1       NaN       NaN
# Goshen College                             0.0         1     548.0     553.0
# Chillicothe Beauty Academy Inc             0.0         0       NaN       NaN
#
#                                      DISTANCEONLY     UGDS  \
# INSTNM
# Greenville Technical College                  0.0  11186.0
# Ivy Tech Community College-Richmond           NaN      NaN
# ...

# %% [markdown]
# - .iloc, .loc 모두 슬라이스 표기를 사용할 수 있다.

# %%
college.iloc[0:2]
# Out:
#                                            CITY STABBR  HBCU  MENONLY  \
# INSTNM
# Alabama A & M University                 Normal     AL   1.0      0.0
# University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
#
#                                      WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# INSTNM
# Alabama A & M University                   0.0         0     424.0     420.0
# University of Alabama at Birmingham        0.0         0     570.0     565.0
#
#                                      DISTANCEONLY     UGDS  \
# INSTNM
# Alabama A & M University                      0.0   4206.0
# University of Alabama at Birmingham           0.0  11383.0
#
#                                             ...          UGDS_2MOR  UGDS_NRA  \
# INSTNM                                      ...
# Alabama A & M University                    ...             0.0000    0.0059
# University of Alabama at Birmingham         ...             0.0368    0.0179
#
# ...

# %%
start = 'Alabama A & M University'
stop = 'University of Alabama at Birmingham'
college.loc[start:stop]
# Out:
#                                            CITY STABBR  HBCU  MENONLY  \
# INSTNM
# Alabama A & M University                 Normal     AL   1.0      0.0
# University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
#
#                                      WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# INSTNM
# Alabama A & M University                   0.0         0     424.0     420.0
# University of Alabama at Birmingham        0.0         0     570.0     565.0
#
#                                      DISTANCEONLY     UGDS  \
# INSTNM
# Alabama A & M University                      0.0   4206.0
# University of Alabama at Birmingham           0.0  11383.0
#
#                                             ...          UGDS_2MOR  UGDS_NRA  \
# INSTNM                                      ...
# Alabama A & M University                    ...             0.0000    0.0059
# University of Alabama at Birmingham         ...             0.0368    0.0179
#
# ...

# %%
college.head()
# Out:
#                                            CITY STABBR  HBCU  MENONLY  \
# INSTNM
# Alabama A & M University                 Normal     AL   1.0      0.0
# University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
# Amridge University                   Montgomery     AL   0.0      0.0
# University of Alabama in Huntsville  Huntsville     AL   0.0      0.0
# Alabama State University             Montgomery     AL   1.0      0.0
#
#                                      WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# INSTNM
# Alabama A & M University                   0.0         0     424.0     420.0
# University of Alabama at Birmingham        0.0         0     570.0     565.0
# Amridge University                         0.0         1       NaN       NaN
# University of Alabama in Huntsville        0.0         0     595.0     590.0
# Alabama State University                   0.0         0     425.0     430.0
#
#                                      DISTANCEONLY     UGDS  \
# ...

# %% [markdown]
# - DataFrame에서 iloc로 row를 선택
# - index로 index label을 선택
# - tolist()로 list로 변환

# %%
college.iloc[[0, 1, 2]].index.tolist()
# Out:
# ['Alabama A & M University',
#  'University of Alabama at Birmingham',
#  'Amridge University']

# %% [markdown]
# ## 3. DataFrame row, col 동시에 선택
#
# - col, row를 동시에 선택하려면 .iloc, .loc indexer에 쉼표로 구분된 정확한 col, row를 동시에 전달해야만 한다.
# - col, row를 지정하는 값은 스칼라, list, 슬라이스 객체, 불리언 배열일 수 있다.

# %% [markdown]
# - 대학 데이터셋을 읽어 들이고 대학 이름을 index로 사용한다.
# - 처음 3개 row, 처음 4개 col을 선택한다.

# %%
college = pd.read_csv('../data/college.csv', index_col='INSTNM')

# %%
college.iloc[:3, :4]
# Out:
#                                            CITY STABBR  HBCU  MENONLY
# INSTNM
# Alabama A & M University                 Normal     AL   1.0      0.0
# University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
# Amridge University                   Montgomery     AL   0.0      0.0

# %%
college.loc[:'Amridge University', :'MENONLY']
# Out:
#                                            CITY STABBR  HBCU  MENONLY
# INSTNM
# Alabama A & M University                 Normal     AL   1.0      0.0
# University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
# Amridge University                   Montgomery     AL   0.0      0.0

# %% [markdown]
# - 서로 다른 2개 col의 모든 row를 선택한다.

# %%
college.iloc[:, [4, 6]].head()
# Out:
#                                      WOMENONLY  SATVRMID
# INSTNM
# Alabama A & M University                   0.0     424.0
# University of Alabama at Birmingham        0.0     570.0
# Amridge University                         0.0       NaN
# University of Alabama in Huntsville        0.0     595.0
# Alabama State University                   0.0     425.0

# %%
college.loc[:, ['WOMENONLY', 'SATVRMID']].head()
# Out:
#                                      WOMENONLY  SATVRMID
# INSTNM
# Alabama A & M University                   0.0     424.0
# University of Alabama at Birmingham        0.0     570.0
# Amridge University                         0.0       NaN
# University of Alabama in Huntsville        0.0     595.0
# Alabama State University                   0.0     425.0

# %% [markdown]
# - 단일 스칼라 값을 선택한다.

# %%
college.iloc[4, -4]
# Out:
# 0.7554

# %%
college.loc['Alabama State University', 'PCTFLOAN']
# Out:
# 0.7554

# %% [markdown]
# - row를 슬라이스하여 단일 col을 선택한다.

# %%
college.iloc[90:80:-2, 5]
# Out:
# INSTNM
# Empire Beauty School-Flagstaff     0
# Charles of Italy Beauty College    0
# Central Arizona College            0
# University of Arizona              0
# Arizona State University-Tempe     0
# Name: RELAFFIL, dtype: int64

# %%
start = 'Empire Beauty School-Flagstaff'
stop = 'Arizona State University-Tempe'
college.loc[start:stop:-2, 'RELAFFIL']
# Out:
# INSTNM
# Empire Beauty School-Flagstaff     0
# Charles of Italy Beauty College    0
# Central Arizona College            0
# University of Arizona              0
# Arizona State University-Tempe     0
# Name: RELAFFIL, dtype: int64

# %% [markdown]
# - 모든 col, 일부 row만 선택할 때는 쉼표 다음에 콜론을 반드시 사용하지 않아도 된다.
# - 쉼표가 없을 때의 디폴트 작동은 모든 col을 선택하는 것이다.
# - 모든 col을 슬라이스 표기로 나타낼 수도 있지만 두 방식은 동일하다.

# %%
college.iloc[:10].head()
# Out:
#                                            CITY STABBR  HBCU  MENONLY  \
# INSTNM
# Alabama A & M University                 Normal     AL   1.0      0.0
# University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
# Amridge University                   Montgomery     AL   0.0      0.0
# University of Alabama in Huntsville  Huntsville     AL   0.0      0.0
# Alabama State University             Montgomery     AL   1.0      0.0
#
#                                      WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# INSTNM
# Alabama A & M University                   0.0         0     424.0     420.0
# University of Alabama at Birmingham        0.0         0     570.0     565.0
# Amridge University                         0.0         1       NaN       NaN
# University of Alabama in Huntsville        0.0         0     595.0     590.0
# Alabama State University                   0.0         0     425.0     430.0
#
#                                      DISTANCEONLY     UGDS  \
# ...

# %%
college.iloc[:10, :].head()
# Out:
#                                            CITY STABBR  HBCU  MENONLY  \
# INSTNM
# Alabama A & M University                 Normal     AL   1.0      0.0
# University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
# Amridge University                   Montgomery     AL   0.0      0.0
# University of Alabama in Huntsville  Huntsville     AL   0.0      0.0
# Alabama State University             Montgomery     AL   1.0      0.0
#
#                                      WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# INSTNM
# Alabama A & M University                   0.0         0     424.0     420.0
# University of Alabama at Birmingham        0.0         0     570.0     565.0
# Amridge University                         0.0         1       NaN       NaN
# University of Alabama in Huntsville        0.0         0     595.0     590.0
# Alabama State University                   0.0         0     425.0     430.0
#
#                                      DISTANCEONLY     UGDS  \
# ...

# %% [markdown]
# ## 4. 정수와 레이블을 동시에 사용하여 데이터 선택

# %% [markdown]
# - pandas 초기 버전에서는 .ix indexer를 이용하여 정수와 레이블을 동시에 사용할 수 있었다.
# - .ix indexer는 사용하지 않도록 한다.
# - 현재는 row를 정수 기반으로 찾은 후 .iloc를 사용하여 선택한다.

# %%
college = pd.read_csv('../data/college.csv', index_col='INSTNM')

# %%
col_start = college.columns.get_loc('UGDS_WHITE')

# %%
col_end = college.columns.get_loc('UGDS_UNKN') + 1

# %%
col_start, col_end
# Out:
# (10, 19)

# %%
college.iloc[:5, col_start:col_end]
# Out:
#                                      UGDS_WHITE  UGDS_BLACK  UGDS_HISP  \
# INSTNM
# Alabama A & M University                 0.0333      0.9353     0.0055
# University of Alabama at Birmingham      0.5922      0.2600     0.0283
# Amridge University                       0.2990      0.4192     0.0069
# University of Alabama in Huntsville      0.6988      0.1255     0.0382
# Alabama State University                 0.0158      0.9208     0.0121
#
#                                      UGDS_ASIAN  UGDS_AIAN  UGDS_NHPI  \
# INSTNM
# Alabama A & M University                 0.0019     0.0024     0.0019
# University of Alabama at Birmingham      0.0518     0.0022     0.0007
# Amridge University                       0.0034     0.0000     0.0000
# University of Alabama in Huntsville      0.0376     0.0143     0.0002
# Alabama State University                 0.0019     0.0010     0.0006
#
#                                      UGDS_2MOR  UGDS_NRA  UGDS_UNKN
# INSTNM
# ...

# %% [markdown]
# - columns attribute는 col index를 반환한다.
# - index는 get_loc() 메서드를 가지고 있고, index label을 인자로 받아 해당하는 정수 위치를 반환한다.
# - iloc는 마지막 원소를 포함하지 않으므로 슬라이스할 때 1을 더해야 한다.

# %% [markdown]
# - .loc가 정수와 label를 모두 사용하여 비슷한 연산을 하도록 할 수 있다.

# %%
row_start = college.index[10]
row_end = college.index[15]

# %%
college.loc[row_start:row_end, 'UGDS_WHITE':'UGDS_UNKN']
# Out:
#                                           UGDS_WHITE  UGDS_BLACK  UGDS_HISP  \
# INSTNM
# Birmingham Southern College                   0.7983      0.1102     0.0195
# Chattahoochee Valley Community College        0.4661      0.4372     0.0492
# Concordia College Alabama                     0.0280      0.8758     0.0373
# South University-Montgomery                   0.3046      0.6054     0.0153
# Enterprise State Community College            0.6408      0.2435     0.0509
# James H Faulkner State Community College      0.6979      0.2259     0.0320
#
#                                           UGDS_ASIAN  UGDS_AIAN  UGDS_NHPI  \
# INSTNM
# Birmingham Southern College                   0.0517     0.0102     0.0000
# Chattahoochee Valley Community College        0.0127     0.0023     0.0035
# Concordia College Alabama                     0.0093     0.0000     0.0000
# South University-Montgomery                   0.0153     0.0153     0.0096
# ...

# %% [markdown]
# - .iloc와 .loc를 chaining하면 같은 결과를 얻을 수 있으나, 일반적으로 indexer를 chaining하는 것은 좋지 않다.

# %% [markdown]
# ## 5. 스칼라 선택 더 빠르게 하기

# %% [markdown]
# - .iloc와 .loc indexer 모두 Series나 DataFrame으로부터 스칼라 값을 선택할 수 있다.
# - 그러나 .iat, .at indexer를 사용하면 동일한 결과를 더 빠르게 수행할 수 있다.

# %%
college = pd.read_csv('../data/college.csv', index_col='INSTNM')

# %%
cn = 'Concordia College Alabama'

# %%
college.loc[cn, 'UGDS_WHITE']
# Out:
# 0.028

# %%
college.at[cn, 'UGDS_WHITE']
# Out:
# 0.028

# %%
# %timeit college.loc[cn, 'UGDS_WHITE']
# Out:
# 8.31 µs ± 26.2 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
# %timeit college.at[cn, 'UGDS_WHITE']
# Out:
# 5.44 µs ± 26.1 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
row_num = college.index.get_loc(cn)

# %%
col_num = college.columns.get_loc('UGDS_WHITE')

# %%
row_num, col_num
# Out:
# (12, 10)

# %%
# %timeit college.iloc[row_num, col_num]
# Out:
# 9.49 µs ± 72.8 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
# %timeit college.iat[row_num, col_num]
# Out:
# 6.06 µs ± 24.6 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %% [markdown]
# - .iat, .at을 스칼라 indexer라고 부른다.
# - 둘 모두 Series에서도 잘 동작한다.

# %%
state = college['STABBR']

# %%
state.iat[1000]
# Out:
# 'IL'

# %%
state.at['Stanford University']
# Out:
# 'CA'

# %% [markdown]
# - timeit 명령어는 2개의 %로 시작하면 코드 블록 전체에 대한 시간을 측정한다.

# %% [markdown]
# ## 6. row를 게으르게 슬라이스

# %% [markdown]
# - row를 선택할 때 index operator만 사용하여 더 간단히 할 수 있는 방법이 있다.
# - 하지만 index operator의 가장 중요한 기능은 DataFrame의 col을 선택하는 것이다.
# - row를 선택하려면 모호성이 없도록 .iloc나 .loc를 사용하는 것이 가장 좋다.

# %%
college = pd.read_csv('../data/college.csv', index_col='INSTNM')

# %% [markdown]
# - index operator에 슬라이스 객체를 전달한다.

# %%
college[10:20:2]
# Out:
#                                              CITY STABBR  HBCU  MENONLY  \
# INSTNM
# Birmingham Southern College            Birmingham     AL   0.0      0.0
# Concordia College Alabama                   Selma     AL   1.0      0.0
# Enterprise State Community College     Enterprise     AL   0.0      0.0
# Faulkner University                    Montgomery     AL   0.0      0.0
# New Beginning College of Cosmetology  Albertville     AL   0.0      0.0
#
#                                       WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# INSTNM
# Birmingham Southern College                 0.0         1     560.0     560.0
# Concordia College Alabama                   0.0         1     420.0     400.0
# Enterprise State Community College          0.0         0       NaN       NaN
# Faulkner University                         0.0         1       NaN       NaN
# New Beginning College of Cosmetology        0.0         0       NaN       NaN
#
# ...

# %% [markdown]
# - Series에도 동일한 슬라이스가 존재한다.

# %%
city = college['CITY']

# %%
city[10:20:2]
# Out:
# INSTNM
# Birmingham Southern College              Birmingham
# Concordia College Alabama                     Selma
# Enterprise State Community College       Enterprise
# Faulkner University                      Montgomery
# New Beginning College of Cosmetology    Albertville
# Name: CITY, dtype: object

# %% [markdown]
# - Series와 DataFrame은 모두 index operator처럼 label로 슬라이스 할 수 있다.

# %%
start = 'Birmingham Southern College'
stop = 'New Beginning College of Cosmetology'
college[start:stop:2]
# Out:
#                                              CITY STABBR  HBCU  MENONLY  \
# INSTNM
# Birmingham Southern College            Birmingham     AL   0.0      0.0
# Concordia College Alabama                   Selma     AL   1.0      0.0
# Enterprise State Community College     Enterprise     AL   0.0      0.0
# Faulkner University                    Montgomery     AL   0.0      0.0
# New Beginning College of Cosmetology  Albertville     AL   0.0      0.0
#
#                                       WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# INSTNM
# Birmingham Southern College                 0.0         1     560.0     560.0
# Concordia College Alabama                   0.0         1     420.0     400.0
# Enterprise State Community College          0.0         0       NaN       NaN
# Faulkner University                         0.0         1       NaN       NaN
# New Beginning College of Cosmetology        0.0         0       NaN       NaN
#
# ...

# %%
city[start:stop:2]
# Out:
# INSTNM
# Birmingham Southern College              Birmingham
# Concordia College Alabama                     Selma
# Enterprise State Community College       Enterprise
# Faulkner University                      Montgomery
# New Beginning College of Cosmetology    Albertville
# Name: CITY, dtype: object

# %% [markdown]
# - `df[item]`이 있을 때
# - item이 문자열이면
#     - 정확히 item과 일치하는 col이름을 찾는다.
#     - 정확히 매치하는 것이 없으면 KeyError를 발생시킨다.
#     - 찾은 col을 Series로 반환한다.
# - item이 문자열 리스트면
#     - item에 있는 하나 또는 그 이상의 문자열에 해당 하는 col이 없으면 KeyError
#     - 리스트와 일치하는 col들로만 구성된 DataFrmae 반환
# - item이 슬라이스 객체면
#     - 정수 또는 슬라이싱 객체와 작업
#     - 레이블 슬라이스에 지정된 레이블이 인덱스에 없으면 KeyError
#     - 슬라이스에 의해 선택된 모든 열을 반환
# - item이 리스트, 불리언의 Series 또는 ndarray면
#     - item의 길이가 DataFrame의 길이와 다르면 ValueError
#     - boolean을 이용해 True 값을 가진 위치에 있는 행들만 반환

# %% [markdown]
# - 이 방법은 col에서는 작동하지 않고 DataFrame의 row와 Series에만 작동한다.
# - row와 col을 동시에 선택할 때는 사용할 수 없다.

# %%
# college[:10, ['CITY', 'STABBR']]
# unhashable type: 'slice'

# %% [markdown]
# - 동시에 선택하려면 .loc나 .iloc를 사용해야 한다.

# %%
first_ten_instnm = college.index[:10]
college.loc[first_ten_instnm, ['CITY', 'STABBR']]
# Out:
#                                                CITY STABBR
# INSTNM
# Alabama A & M University                     Normal     AL
# University of Alabama at Birmingham      Birmingham     AL
# Amridge University                       Montgomery     AL
# University of Alabama in Huntsville      Huntsville     AL
# Alabama State University                 Montgomery     AL
# The University of Alabama                Tuscaloosa     AL
# Central Alabama Community College    Alexander City     AL
# Athens State University                      Athens     AL
# Auburn University at Montgomery          Montgomery     AL
# Auburn University                            Auburn     AL

# %% [markdown]
# ## 7. 사전 순서대로 슬라이스
# - .loc indexer는 대개 인덱스의 정확한 문자열에 기반해 선택한다.
# - 그러나 인덱스의 사전 순서에 의해 데이터를 선택할 수 있는 방법도 제공한다.
# - 특히 .loc를 사용하면 슬라이스 표기법을 사용해 인덱스를 사전 순서로 row를 선택할 수 잇다.
# - 이 방법은 인덱스가 정렬되어 있을 경우에만 사용할 수 있다.

# %% [markdown]
# - 대학 데이터셋을 읽어들인 후 대학 이름을 index로 사용한다.

# %%
college = pd.read_csv('../data/college.csv', index_col='INSTNM')

# %% [markdown]
# - Sp와 Su 사이의 모든 대학 이름을 사전 순서대로 선택해보자.

# %%
# college.loc['Sp':'Su']
# KeyError: 'Sp'

# %% [markdown]
# - index가 정렬되어 있지 않으므로 오류가 발생한다.

# %% [markdown]
# - index를 정렬해보자.

# %%
college = college.sort_index()

# %%
college.loc['Sp':'Su']
# Out:
#                                                                  CITY STABBR  \
# INSTNM
# Spa Tech Institute-Ipswich                                    Ipswich     MA
# Spa Tech Institute-Plymouth                                  Plymouth     MA
# Spa Tech Institute-Westboro                                  Westboro     MA
# Spa Tech Institute-Westbrook                                Westbrook     ME
# Spalding University                                        Louisville     KY
# Spanish-American Institute                                   New York     NY
# Spartan College of Aeronautics & Technology                 Inglewood     CA
# Spartan College of Aeronautics and Technology                   Tulsa     OK
# Spartanburg Community College                             Spartanburg     SC
# Spartanburg Methodist College                             Spartanburg     SC
# Specs Howard School of Media Arts                          Southfield     MI
# ...

# %% [markdown]
# - .loc의 일반적 작동은 전달된 정확한 label에 기반해 데이터를 선택하는 것이다.
# - index에서 이 값을 찾을 수 없으면 KeyError가 발생한다.
# - 이 작동 방식의 한 가지 예외는 index가 사전 순서대로 정렬되어 있을 때 슬라이스가 전달됐을 경우다.
# - 이 경우 start와 stop label 사이의 모든 index가 마치 정확한 값인 것처럼 전부 선택된다.

# %% [markdown]
# - 이 방식을 사용하면 두 알파벳 사이의 모든 대학을 선택하는 것이 용이해진다.
# - 예들 들어, D와 S 사이의 이름을 가진 모든 대학을 선택하려면 college.loc['D':'T']
# - 슬라이싱은 마지막 인덱스를 포함하므로 대학 이름이 T인 학교까지 값을 찾아 반환한다.

# %%
college = college.sort_index(ascending=False)

# %%
college.head()
# Out:
#                                                       CITY STABBR  HBCU  \
# INSTNM
# eClips School of Cosmetology and Barbering  Cape Girardeau     MO   0.0
# duCret School of Arts                           Plainfield     NJ   0.0
# Zane State College                              Zanesville     OH   0.0
# Z Hair Academy                                    Lawrence     KS   0.0
# Yukon Beauty College Inc                             Yukon     OK   0.0
#
#                                             MENONLY  WOMENONLY  RELAFFIL  \
# INSTNM
# eClips School of Cosmetology and Barbering      0.0        0.0         0
# duCret School of Arts                           0.0        0.0         0
# Zane State College                              0.0        0.0         0
# Z Hair Academy                                  0.0        0.0         0
# Yukon Beauty College Inc                        0.0        0.0         0
#
# ...

# %%
college.index.is_monotonic_decreasing
# Out:
# True

# %%
college.index.is_monotonic_increasing
# Out:
# False

# %%
college.loc['E':'B']
# Out:
#                                                                 CITY STABBR  \
# INSTNM
# Dyersburg State Community College                          Dyersburg     TN
# Dutchess Community College                              Poughkeepsie     NY
# Dutchess BOCES-Practical Nursing Program                Poughkeepsie     NY
# Durham Technical Community College                            Durham     NC
# Durham Beauty Academy                                         Durham     NC
# Duquesne University                                       Pittsburgh     PA
# Dunwoody College of Technology                           Minneapolis     MN
# Duluth Business University                                    Duluth     MN
# Duke University                                               Durham     NC
# DuVall's School of Cosmetology                               Bedford     TX
# Du Bois Business College-Oil City                           Oil City     PA
# ...
