# %% [markdown]
# # Ticker 변경

# %%
import numpy as np
import pandas as pd

# %%
dividend = pd.read_csv('./data/dividend_data.csv', index_col='DATE')

# %%
dividend.head()
# Out:
#            TICKER  DIVIDEND
# DATE
# 2016-02-15   AAPL      0.88
# 2016-02-22   SBUX      0.85
# 2016-03-09    JNJ      1.27
# 2016-03-29    BAC      0.34
# 2016-04-05     KO      0.89

# %%
# TICKER 컬럼에 어떤 값이 있는지 확인
set(dividend['TICKER'])
# Out:
# {'AAPL',
#  'BAC',
#  'BND',
#  'GS',
#  'JNJ',
#  'KO',
#  'MO',
#  'NVDA',
#  'O',
#  'PG',
#  'PM',
#  'SBUX',
#  'T',
#  'Vanguard',
#  'WSR'}

# %%
# Vanguard를 BND로 변경하고 싶다.
dividend[dividend['TICKER']=='Vanguard']
# Out:
#               TICKER  DIVIDEND
# DATE
# 2017-03-09  Vanguard      0.67
# 2017-04-10  Vanguard      0.74
# 2017-05-10  Vanguard      0.71
# 2017-06-09  Vanguard      0.73
# 2017-07-11  Vanguard      0.72
# 2017-08-08  Vanguard      0.73
# 2017-09-11  Vanguard      0.74
# 2017-10-11  Vanguard      0.71
# 2017-11-07  Vanguard      0.73
# 2017-12-07  Vanguard      0.71
# 2018-01-02  Vanguard      0.19
# 2018-01-02  Vanguard      0.74
# 2018-02-07  Vanguard      0.75
# 2018-03-07  Vanguard      0.71
# 2018-04-05  Vanguard      0.10
# 2018-04-05  Vanguard      0.77
# 2018-04-09  Vanguard      0.11
# 2018-04-10  Vanguard      0.11
# 2018-04-12  Vanguard      0.11
# 2018-04-12  Vanguard      0.11
# 2018-04-12  Vanguard      0.11
# 2018-04-12  Vanguard      0.11
# 2018-04-13  Vanguard      0.11
# 2018-04-13  Vanguard      0.11
# 2018-04-13  Vanguard      0.11
# 2018-04-13  Vanguard      0.10
# 2018-05-08  Vanguard      0.76
# 2018-06-08  Vanguard      0.78
# 2018-07-06  Vanguard      0.77
# 2018-08-06  Vanguard      0.80
# 2018-09-06  Vanguard      0.80

# %%
dividend = dividend.replace({'TICKER': 'Vanguard'}, {'TICKER': 'BND'})

# %%
dividend[dividend['TICKER']=='Vanguard']
# Out:
# Empty DataFrame
# Columns: [TICKER, DIVIDEND]
# Index: []

# %%
set(dividend['TICKER'])
# Out:
# {'AAPL',
#  'BAC',
#  'BND',
#  'GS',
#  'JNJ',
#  'KO',
#  'MO',
#  'NVDA',
#  'O',
#  'PG',
#  'PM',
#  'SBUX',
#  'T',
#  'WSR'}

# %%
dividend.to_csv('./data/dividend_data.csv')
