# %% [markdown]
# ## TKX 피트니스에 오신 것을 환영합니다!
#
# 안녕하세요! TKX 피트니스 데이터분석팀에 오신 것을 환영합니다.
#
# TKX는 국내 최대의 프렌차이즈 피트니스 센터로서, 매월 수 천명에 달하는 신규 회원을 받아 데이터를 분석하고 있습니다.
#
# TKX 피트니스의 장점은 프로그래밍 언어 파이썬(Python)과 데이터 분석 프레임워크 판다스(Pandas)를 활용한 면밀한 데이터 분석입니다. 이 데이터 분석을 바탕으로 KTX의 오퍼레이션 팀 / 코칭 팀은 피트니스 센터에 방문하는 고객 분들, 그리고 방문하지 않는 고객 분들에게도 최선의 맞춤 서비스를 제공해 드리고 있습니다.
#
# 오늘 이 노트북을 받은 분이 해주셔야 하는 일은 2016년도 1월부터 2017년도 12월까지의 신규 가입 고객 데이터를 받아와, 차후에 데이터분석을 더 용이하게 할 수 있도록 데이터를 정리해주는 작업, 일명 데이터 클리닝(Data Cleaning) 작업입니다.
#
# 저희 TKX 피트니스는 언제나 잘 정리되어 있는 고객 정보를 받아서 데이터 분석팀에게 맡길려고 노력하고 있으나, (이 노트북을 받은 분들도 아시겠지만) 현실은 언제나 100% 잘 정리되어있는 데이터를 받아오기가 어렵습니다.
#
# 때문에 이번 시간에는 신규 가입 고객 데이터를 분석하여, 데이터에 몇몇 누락된 부분이나 잘못 기입된 부분 등을 판다스로 정리하고 그 결과를 분석하는 일을 해주셨으면 합니다.
#
# 데이터는 다음의 URL [https://goo.gl/8XGH4T](https://goo.gl/8XGH4T) 에서 다운받을 수 있습니다. 데이터를 다운받아 읽어온 뒤, 하기에 적어놓은 내용대로 데이터를 분석 및 정리를 해주세요.

# %%
import pandas as pd

# %% [markdown]
# ## Load Dataset

# %%
data = pd.read_csv("tkx-user-data.csv")

print(data1.shape)
data1.head()
# Out:
# (106839, 13)
#     이름  성별           전화번호   나이 현재 체중 목표 체중    키         회원 가입일      회원 정보 갱신일  \
# 0  안원준  남성  010-2292-6251  31세    78    68  176  2016년 07월 05일  2016년 07월 05일
# 1  유세아  여성    01045795881   39  56kg  51kg  172  2016년 10월 02일  2016년 11월 29일
# 2  송솔은  여성  010-7719-8346    0    29    21  167  2017년 09월 06일  2017년 09월 06일
# 3  백서원  여성    01011947169   36    67    65    0  2017년 06월 02일  2017년 07월 28일
# 4  박서은  여성  010-2575-6398   42    60    57  167  2017년 05월 07일  2017년 05월 07일
#
#   흡연 여부 음주 여부 가입 개월 수 개인상담 요청
# 0   아니오  주 1회     0개월     아니요
# 1     예  월 1회     0개월     아니요
# 2     예  주 1회     0개월     아니요
# 3     예  안 마심     0개월     아니요
# 4   아니오  안 마심     0개월       예

# %% [markdown]
# ## 실습

# %% [markdown]
# ** 1. 텍스트로 된 흡연 여부(예/아니오)를 True/False 로 바꾸기 **

# %%
# Write code here!
data.loc[data['흡연 여부'] == '예','흡연 여부'] = True
#pd.isnull(data.loc[2,'나이'])

# %% [markdown]
# ** 2. 나이에서 0세라고 되어있는 것을 NaN으로 바꾸기 **

# %%
# Write code here!
#import numpy as np
#data.loc[data['Age'] == '0','Age']=np.nan
data
# Out:
#        Name  Gender   Phone Number   Age  Current Weight  Goal Weight  Height  \
# 106822                   예        6개월
# 106823                 아니요         무료
# 106824                 아니요         무료
# 106825                 아니요         무료
# 106826                 아니요         무료
# 106827                 아니요         무료
# 106828                 아니요         무료
# 106829                   예        3개월
# 106830                 아니요        3개월
# 106831                 아니요         무료
# 106832                 아니요         무료
# 106833                 아니요         무료
# 106834                 아니요         무료
# 106835                 아니요         무료
# 106836                 아니요         무료
# 106837                   예         무료
# 106838                 아니요        3개월
#
# [106839 rows x 14 columns]

# %% [markdown]
# ** 3. 나이 컬럼을 정리하기 **

# %%
# Write code here!
def ass(age):
    if pd.isnull(age):
        return age
    if ' 세' in age:
        age = age.replace(' 세','')
        return int(age)
    if '세' in age:
        age = age.replace('세','')
        return int(age)
    return int(age)

data['나이'] = data['나이'].apply(ass)

# %% [markdown]
# ** 4. 평균(mean) / 최소(min) / 최대(max) 나이 구하기 **

# %%
# Write code here!
data['나이'].mean()
aas = pd.DataFrame(data['나이'].value_counts())

# %% [markdown]
# ** 5. 컬럼의 순서를 조금 더 직관적으로 바꾸기 **

# %%
# Write code here!
data['Drinking'].unique()
# Out:
# array(['주 1회', '월 1회', '안 마심', '월 2회', '주 2회'], dtype=object)

# %% [markdown]
# ## 과제(초급)

# %% [markdown]
# ### 데이터를 사용하기 용이하게 정리하기

# %% [markdown]
# **6. 컬럼 이름 바꾸기**
#
# 보통 프로그래밍을 할 때 한글 컬럼을 사용하면 다양한 문제로 불편을 겪을 때가 많습니다.
#
# 그러므로 컬럼을 전부 한글에서 영어로 바꿔주세요. 컬럼명은 다음과 같이 바꿔주시면 됩니다.
#
# * 이름 - Name
# * 성별 - Gender
# * 전화번호 - Phone Number
# * 나이 - Age
# * 현재 체중 - Current Weight
# * 목표 체종 - Goal Weight
# * 키 - Height
# * 흡연 여부 - Smoking
# * 음주 여부 - Drinking
# * 개인상담 요청 - Request Counselling
# * 회원 가입일 - Joined At
# * 회원 정보 갱신일 - Updated At
# * 가입 개월 수 - Paid Plan

# %% [markdown]
# ** 7. '상담 요청' 컬럼을 예/아니오 에서 True/False로 바꿔주세요 **

# %%
# Write e here!
ddd = ['Name','Gender','Phone Number','Age','Current Weight','Goal Weight','Height','Joined At','Updated At','Smoking','Drinking','Paid Plan','Request Counselling']
data.columns = ddd

# %% [markdown]
# **8. '가입 개월 수' 컬럼을 분석해서, 무료(0개월)인 경우를 True로, 유료인 경우(3, 6, 9, 12개월)를 False로 보여주는 새로운 컬럼을 만들어주세요.**

# %%
# Write code here!
data.loc[data['Paid Plan'] != True ,'Paid Plan'] = False

# %% [markdown]
# ### 컬럼의 형태를 하나로 통일하고, 빈 값이나 outlier들을 NaN으로 바꾸기

# %% [markdown]
# ** 9. 전화번호 컬럼을 정리해주세요. 다음과 같이 정리해주시면 됩니다. **
#   * unknown 이라고 표시되어 있는 전화번호는 빈 전화번호입니다. 이를 NaN으로 바꿔주세요.

# %%
# Write code here!
import numpy as np
data.loc[data['Phone Number'] == 'unknown','Phone Number'] = np.nan
data['Phone Number'].unique()
#data.head()
# Out:
# array(['010-2292-6251', '01045795881', '010-7719-8346', ...,
#        '01026978245', '01012368947', '010-3573-3763'], dtype=object)

# %% [markdown]
# ** 10. 키(cm) 컬럼을 정리해주세요. 다음과 같이 정리해주시면 됩니다.**
#
# * 다양한 형태로 표현되어 있는 키 컬럼(?, ?cm, ? cm 등)을 숫자로 통일해주세요.
# * 키가 0으로 되어있으면 NaN으로 바꿔주세요.
# * 키가 너무 작거나(140cm 이하) 너무 크면(210cm 이상) 마찬가지로 NaN으로 바꿔주세요.

# %%
# Write code here!
def fdd(height):
    if pd.isnull(height):
        return height
    if ' cm' in height:
        height = height.replace(' cm','')
        return int(height)
    if 'cm' in height:
        height = height.replace('cm','')
        return int(height)
    return int(height)

data['Height'] = data['Height'].apply(fdd)
data.loc[(data['Height'] >=210) | (data['Height'] <=140),'Height']=np.nan

# %% [markdown]
# ** 11.'현재 체중'과	'목표 체중' 컬럼을 정리해주세요. 다음과 같이 정리해주시면 됩니다.**
#
# * 다양한 형태로 표현되어 있는 몸무게 컬럼(?, ?kg, ? kg 등)을 숫자로 통일해주세요.
# * 몸무게가 0으로 되어있으면 NaN으로 바꿔주세요.
# * 몸무게가 너무 작거나(40kg 이하) 너무 크면(150kg 이상) 마찬가지로 NaN으로 바꿔주세요.

# %%
# Write code here!
def fdd(height):
    if pd.isnull(height):
        return height
    if ' kg' in height:
        height = height.replace(' kg','')
        return int(height)
    if 'kg' in height:
        height = height.replace('kg','')
        return int(height)
    return int(height)
data['Goal Weight'] = data['Goal Weight'].apply(fdd)
data.loc[(data['Goal Weight'] >=150) | (data['Goal Weight'] <=40),'Goal Weight']=np.nan

# %% [markdown]
# ### 기본적인 분석을 하기

# %% [markdown]
# ** 12. 전체 데이터에서 평균/최소/최대 키(cm), 그리고 평균/최소/최대 '현재 체중(kg)'과 '목표 체중(kg)'을 찾아주세요. **

# %%
# Write code here!
print("평균 키 : %d" % data['Height'].mean())
print("최소 키 : %d" % data['Height'].min())
print("최대 키 : %d" % data['Height'].max())
print('----------------------------')
print("평균 현재체중 : %d" % data['Current Weight'].mean())
print("최소 현재체중 : %d" % data['Current Weight'].min())
print("최대 현재체중 : %d" % data['Current Weight'].max())
print('----------------------------')
print("평균 목표체중 : %d" % data['Goal Weight'].mean())
print("최소 목표체중 : %d" % data['Goal Weight'].min())
print("최대 목표체중 : %d" % data['Goal Weight'].max())
# Out:
# 평균 키 : 172
# 최소 키 : 148
# 최대 키 : 209
# ----------------------------
# 평균 현재체중 : 71
# 최소 현재체중 : 44
# 최대 현재체중 : 149
# ----------------------------
# 평균 목표체중 : 66
# 최소 목표체중 : 41
# 최대 목표체중 : 148

# %% [markdown]
# ** 13. 전체 데이터에서 흡연자와 비흡연자 인원의 총합을 찾아주세요. **

# %%
print('흡연자 : %d' % data.loc[data['Smoking'] == True,'Smoking'].value_counts())
print('비흡연자 : %d' % data.loc[data['Smoking'] == False,'Smoking'].value_counts())
# Out:
# 흡연자 : 21371
# 비흡연자 : 85468

# %% [markdown]
# ** 14. 전체 데이터에서 유료 사용자와 무료 사용자의 인원의 총합을 찾아주세요. **
#
# 또한 유료 사용자만 한정해서, 3개월 / 6개월 / 12개월 결제자의 인원의 총합을 찾아주세요.

# %%
# Write code here!
#data['Paid Plan'].value_counts()
print("3개월 사용자 : %d" % data.loc[data['Paid Plan1'] == '3개월','Paid Plan1'].value_counts())
print("6개월 사용자 : %d" % data.loc[data['Paid Plan1'] == '6개월','Paid Plan1'].value_counts())
print("12개월 사용자 : %d" % data.loc[data['Paid Plan1'] == '12개월','Paid Plan1'].value_counts())
print('----------------------------')
print("유료 사용자 : %d" % data.loc[data['Paid Plan'] == False,'Paid Plan'].value_counts())
print("무료 사용자 : %d" % data.loc[data['Paid Plan'] == True,'Paid Plan'].value_counts())
# Out:
# 3개월 사용자 : 21250
# 6개월 사용자 : 7291
# 12개월 사용자 : 3343
# ----------------------------
# 유료 사용자 : 31884
# 무료 사용자 : 74955

# %% [markdown]
# ** 15. 전체 데이터에서 흡연자와 음주 여부를 바탕으로 다음을 분석해주세요. **
#   1. 흡연과 음주를 둘 다 안 하는 사람의 인원 총합.
#   1. 흡연은 하지만 음주는 안 하는 사람의 인원 총합.
#   1. 흡연은 하지 않지만 음주는 하는 사람의 인원 총합.
#   1. 흡연과 음주를 둘 다 하는 사람의 인원 총합.

# %%
# Write code here!

print('흡연/음주 다 x 인원 : %d' % data.loc[data['흡연여부'] == 1,'흡연여부'].value_counts())
print('흡연o/음주x  : %d' % data.loc[data['흡연여부'] == 2,'흡연여부'].value_counts())
print('흡연x/음주0  : %d' % data.loc[data['흡연여부'] == 3,'흡연여부'].value_counts())
# Out:
# 흡연/음주 다 x 인원 : 8488
# 흡연o/음주x  : 2093
# 흡연x/음주0  : 76980

# %% [markdown]
# # 과제(중급)

# %% [markdown]
# ** 16. 성별 컬럼을 정리하기 **
#
# 성별 컬럼을 정리해주세요.
#
# 데이터를 분석해보면 남성, 여성, 남, 녀, Male, FEMALE 등의 다양한 표현이 있습니다. 이 표현을 male, female으로 통일해주세요.

# %%
# Write code here!
data['Gender'].unique()
# Out:
# array(['남성', '여성', 'Male', 'female', 'male', '여', '남', 'Female', 'FEMALE',
#        'MALE'], dtype=object)

# %% [markdown]
# **17. 전체 인원이 아닌, 남성/여성 각각의 최소/평균/최대 키/몸무게/나이를 구해주세요.**
#
# 결과적으로 다음의 수치가 나와야 합니다.
#   * 전체 남성의 최소/평균/최대 나이
#   * 전체 남성의 최소/평균/최대 몸무게(kg)
#   * 전체 남성의 최소/평균/최대 키(cm)
#
#   * 전체 여성의 최소/평균/최대 나이
#   * 전체 여성의 최소/평균/최대 몸무게(kg)
#   * 전체 여성의 최소/평균/최대 키(cm)

# %%
# Write code here!

# %% [markdown]
# ** 18. 감량 목표를 분석하기 **
#
# 데이터에서 '현재 체중' - '목표 체중' 을 하면 감량 목표가 나올 것입니다. 감량 목표를 찾아서 새로운 컬럼을 만들어주세요.
#
# 또한 kg별로 감량을 원하는 사람의 총 인원을 구해주세요. 가령 1) 1kg 감량을 원하는 총 인원, 2) 2kg 감량을 원하는 총 인원, ... 10) 10kg 감량을 원하는 총 인원이 나와야 합니다.

# %%
# Write code here!
#data['Goal'] = data['Current Weight'] - data['Goal Weight']
#s = pd.DataFrame(data['Goal'].value_counts())
s.columns = 'kg'
s.sort_values(by='kg')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-131-636ca8b35d1d> in <module>()
#       2 #data['Goal'] = data['Current Weight'] - data['Goal Weight']
#       3 #s = pd.DataFrame(data['Goal'].value_counts())
# ----> 4 s.columns = 'kg'
#       5 s.sort_values(by='kg')
#
# c:\programdata\anaconda3\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    3625         try:
#    3626             object.__getattribute__(self, name)
# -> 3627             return object.__setattr__(self, name, value)
#    3628         except AttributeError:
#    3629             pass
#
# pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# c:\programdata\anaconda3\lib\site-packages\pandas\core\generic.py in _set_axis(self, axis, labels)
#     557
#     558     def _set_axis(self, axis, labels):
# --> 559         self._data.set_axis(axis, labels)
#     560         self._clear_item_cache()
#     561
#
# c:\programdata\anaconda3\lib\site-packages\pandas\core\internals.py in set_axis(self, axis, new_labels)
#    3065
#    3066     def set_axis(self, axis, new_labels):
# -> 3067         new_labels = _ensure_index(new_labels)
#    3068         old_len = len(self.axes[axis])
#    3069         new_len = len(new_labels)
#
# c:\programdata\anaconda3\lib\site-packages\pandas\core\indexes\base.py in _ensure_index(index_like, copy)
#    4210             index_like = copy(index_like)
#    4211
# -> 4212     return Index(index_like)
#    4213
#    4214
#
# c:\programdata\anaconda3\lib\site-packages\pandas\core\indexes\base.py in __new__(cls, data, dtype, copy, name, fastpath, tupleize_cols, **kwargs)
#     353                          **kwargs)
#     354         elif data is None or is_scalar(data):
# --> 355             cls._scalar_data_error(data)
#     356         else:
#     357             if (tupleize_cols and isinstance(data, list) and data and
#
# c:\programdata\anaconda3\lib\site-packages\pandas\core\indexes\base.py in _scalar_data_error(cls, data)
#     708         raise TypeError('{0}(...) must be called with a collection of some '
#     709                         'kind, {1} was passed'.format(cls.__name__,
# --> 710                                                       repr(data)))
#     711
#     712     @classmethod
#
# TypeError: Index(...) must be called with a collection of some kind, 'kg' was passed

# %% [markdown]
# ** 19. '가입 개월 수'를 숫자로 표현하기 **
#
# '가입 개월 수' 컬럼을 숫자로 정리해주세요. 현재 3개월, 6개월, 12개월로 되어있는데, 이를 3, 6, 12로 정리하시면 됩니다.
#
# 또한 0개월은 0이 아닌 NaN으로 집어넣어 주세요.

# %%
# Write code here!
def qm(pi):
    if pi == '무료':
        return np.nan
    if '개월' in pi:
        pi = pi.replace('개월','')
        return int(pi)
    
data['Paid Plan1'] = data['Paid Plan1'].apply(qm)

# %% [markdown]
# ** 20. '음주 여부'를 숫자로 표현하기**
#
# '음주 여부' 컬럼을 숫자로 정리해주세요. 현재 1) 주 2회, 2) 주 1회, 3) 월 2회, 4) 월 1회 5) 안 마심으로 되어 있습니다만, 이를 월 기준 음주 횟수로 통일해주세요. 여기서 월은 30일로, 주는 4주로 고정합니다.
#
# 가령 1) 주 2회는 8, 2) 주 1회는 4, 3) 월 2회는 2, 4) 월 1회는 1, 5) 안 마심은 0으로 표현하면 됩니다.

# %%
# Write code here!
a[1]
# Out:
# '01045795881'

# %% [markdown]
# ## 과제(고급)

# %% [markdown]
# ** 21.휴대폰 번호 정리하기 **
#
# 다양한 표현으로 되어있는 휴대폰 번호를 010-xxxx-xxxx 로 통일해주세요. 가령 휴대폰 번호에 하이픈이 없으면 넣어주시면 됩니다.
#
# 또한 unknown으로 되어있거나 비어있는 값은 NaN으로 처리해주세요.

# %%
# Write code here!
def qm(pi):
    if '-' in pi:
        pi = pi.replace('-','')
        return pi
    return pi
    
data['Phone Number'] = data['Phone Number'].apply(qm)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-115-40444cd062e6> in <module>()
#       6     return pi
#       7
# ----> 8 data['Phone Number'] = data['Phone Number'].apply(qm)
#
# c:\programdata\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    2549             else:
#    2550                 values = self.asobject
# -> 2551                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    2552
#    2553         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src/inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-115-40444cd062e6> in qm(pi)
#       1 # Write code here!
#       2 def qm(pi):
# ----> 3     if '-' in pi:
#       4         pi = pi.replace('-','')
#       5         return pi
#
# TypeError: argument of type 'float' is not iterable

# %% [markdown]
# ** 22. 날짜를 사용 가능하게 정리하기 **
#
# 현재 '회원 가입일' 컬럼과 '회원 정보 갱신일' 컬럼은 20xx년 xx월 xx일 과 같은 형식으로 되어있습니다.
#
# 이 데이터를 현재 판다스에서는 날짜 컬럼이 아닌 문자열(텍스트) 컬럼으로 인식하고 있는데, 이 컬럼을 날짜 컬럼으로 인식할 수 있도록 수정해주세요.

# %%
# Write code here!
data['Phone Number']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-111-47c86edc000f> in <module>()
#       1 # Write code here!
#       2
# ----> 3 data.loc['-' in data['Phone Number'],'Phone Number'] = data.replace('-','')
#
# c:\programdata\anaconda3\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     192             key = com._apply_if_callable(key, self.obj)
#     193         indexer = self._get_setitem_indexer(key)
# --> 194         self._setitem_with_indexer(indexer, value)
#     195
#     196     def _has_valid_type(self, k, axis):
#
# c:\programdata\anaconda3\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer(self, indexer, value)
#     330                     # reindex the axis to the new value
#     331                     # and set inplace
# --> 332                     key, _ = convert_missing_indexer(idx)
#     333
#     334                     # if this is the items axes, then take the main missing
#
# c:\programdata\anaconda3\lib\site-packages\pandas\core\indexing.py in convert_missing_indexer(indexer)
#    2047
#    2048         if isinstance(indexer, bool):
# -> 2049             raise KeyError("cannot use a single bool to index into setitem")
#    2050         return indexer, True
#    2051
#
# KeyError: 'cannot use a single bool to index into setitem'

# %% [markdown]
# ** 23. 날짜를 기준으로 분석하기 **
#
# 22번에서 날짜 컬럼을 만들었으면 다음을 분석해주세요.
#
# 1. 월별 전체 회원 가입량
# 2. 월 별 유료/무료 회원 가입량의 차이
# 3. 월 별 남성/여성 회원 가입량의 차이

# %%
# Write code here!

# %% [markdown]
# ** 24. 회원 정보가 맞는지 여부를 확인하는 컬럼을 만들기 **
#
# 더 정확한 데이터 분석을 위해서는, 현재까지 고객님이 기업한 회원 정보가 정확한지를 확인하는 작업이 필요합니다. 분석팀에서 데이터를 다음과 같이 정리하면, 오퍼레이션 팀과 코칭 팀이 협업을 통해서 고객 정보를 개선하고, 더 좋은 서비스를 제공할 수 있을 것 같습니다. 다음의 내용이 담겨있는 새로운 컬럼을 하나 만들어주세요. 해당 컬럼에는 reject / counselling / duplicated / confirmed 라는 결과값이 들어가야 합니다.
#
# 다음의 경우에는 재기입을 요청한다. (reject)
# * 전화번호가 비어있는 경우
#
# 다음의 경우는 트레이너와 상담을 유도한다. (counselling)
# * 상담 요청(counselling)이 True인 사람.
#
# 다음의 경우에는 중복을 확인한다. (duplicated)
# * 동일한 이름에 동일한 전화번호를 찾아낸다. 이는 중복되었다고 가정한다.
#
# 나머지는 문제가 없다. (confirmed)

# %%
# Write code here!

# %% [markdown]
# **25. VIP 찾아내기**
#
# 다음의 고객을 특별 관리 대상으로 지정합니다. 특별 관리 대상이라고 함은, TKX 서비스의 VIP 플랜을 구매할 확률이 높은 분들을 의미합니다.
#
# 1. 트레이너와 상담을 요청한 사람. (counselling)
# 2. 상담을 요청하지 않은 사람 중, (현재 체중 - 목표 체중) 이 가장 높은 상위 1,000 명.
#
# 이 사람들을 특별관리 대상으로 지정하며, VIP라는 이름의 컬럼에 True 값을 넣으면 됩니다. 이후에는 오퍼레이션/코치 팀이 해당 고객님을 개별 컨택하여, 적극적으로 VIP 플랜을 구매하실 수 있도록 노력할 생각입니다. (특별관리 대상이 아닌 분들은 VIP 컬럼에 False 값을 넣으면 됩니다)
#
# 또한 전체 데이터와는 별개로, VIP 고객들만을 따로 뽑아내서 CSV파일로 저장할 수 있다면 좋겠습니다.

# %%
# Write code here!
