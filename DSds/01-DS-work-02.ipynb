# %% [markdown]
# ## TKX 피트니스에 오신 것을 환영합니다!
#
# 안녕하세요! TKX 피트니스 데이터분석팀에 오신 것을 환영합니다.
#
# TKX는 국내 최대의 프렌차이즈 피트니스 센터로서, 매월 수 천명에 달하는 신규 회원을 받아 데이터를 분석하고 있습니다.
#
# TKX 피트니스의 장점은 프로그래밍 언어 파이썬(Python)과 데이터 분석 프레임워크 판다스(Pandas)를 활용한 면밀한 데이터 분석입니다. 이 데이터 분석을 바탕으로 KTX의 오퍼레이션 팀 / 코칭 팀은 피트니스 센터에 방문하는 고객 분들, 그리고 방문하지 않는 고객 분들에게도 최선의 맞춤 서비스를 제공해 드리고 있습니다.
#
# 오늘 이 노트북을 받은 분이 해주셔야 하는 일은 2016년도 1월부터 2017년도 12월까지의 신규 가입 고객 데이터를 받아와, 차후에 데이터분석을 더 용이하게 할 수 있도록 데이터를 정리해주는 작업, 일명 데이터 클리닝(Data Cleaning) 작업입니다.
#
# 저희 TKX 피트니스는 언제나 잘 정리되어 있는 고객 정보를 받아서 데이터 분석팀에게 맡길려고 노력하고 있으나, (이 노트북을 받은 분들도 아시겠지만) 현실은 언제나 100% 잘 정리되어있는 데이터를 받아오기가 어렵습니다.
#
# 때문에 이번 시간에는 신규 가입 고객 데이터를 분석하여, 데이터에 몇몇 누락된 부분이나 잘못 기입된 부분 등을 판다스로 정리하고 그 결과를 분석하는 일을 해주셨으면 합니다.
#
# 데이터는 다음의 URL [https://goo.gl/8XGH4T](https://goo.gl/8XGH4T) 에서 다운받을 수 있습니다. 데이터를 다운받아 읽어온 뒤, 하기에 적어놓은 내용대로 데이터를 분석 및 정리를 해주세요.

# %% [markdown]
# ## Load Dataset

# %%
import numpy as np
import pandas as pd
from pandas import DataFrame, Series

# %%
users = pd.read_csv('./data/USER_INFO_07.csv')

# %%
users.head()
# Out:
#   Name Gender   Age  Height  Current Weight  Goal Weight  Smoking Drinking  \
# 0  안원준     남성  31.0   176.0            78.0         68.0    False     주 1회
# 1  유세아     여성  39.0   172.0            56.0         51.0     True     월 1회
# 2  송솔은     여성   NaN   167.0             NaN          NaN     True     주 1회
# 3  백서원     여성  36.0     NaN            67.0         65.0     True     안 마심
# 4  박서은     여성  42.0   167.0            60.0         57.0    False     안 마심
#
#     Phone Number  Request Counselling Paid Plan      Joined At     Updated At  \
# 0  010-2292-6251                False       0개월  2016년 07월 05일  2016년 07월 05일
# 1    01045795881                False       0개월  2016년 10월 02일  2016년 11월 29일
# 2  010-7719-8346                False       0개월  2017년 09월 06일  2017년 09월 06일
# 3    01011947169                False       0개월  2017년 06월 02일  2017년 07월 28일
# 4  010-2575-6398                 True       0개월  2017년 05월 07일  2017년 05월 07일
#
#    Is Free  IsDrinking
# 0     True         1.0
# 1     True         1.0
# 2     True         1.0
# 3     True         0.0
# 4     True         0.0

# %%
users.shape
# Out:
# (106839, 15)

# %% [markdown]
# # 과제(중급)

# %% [markdown]
# ** 16. 성별 컬럼을 정리하기 **
#
# 성별 컬럼을 정리해주세요.
#
# 데이터를 분석해보면 남성, 여성, 남, 녀, Male, FEMALE 등의 다양한 표현이 있습니다. 이 표현을 male, female으로 통일해주세요.

# %%
users.head()
# Out:
#   Name Gender   Age  Height  Current Weight  Goal Weight  Smoking Drinking  \
# 0  안원준     남성  31.0   176.0            78.0         68.0    False     주 1회
# 1  유세아     여성  39.0   172.0            56.0         51.0     True     월 1회
# 2  송솔은     여성   NaN   167.0             NaN          NaN     True     주 1회
# 3  백서원     여성  36.0     NaN            67.0         65.0     True     안 마심
# 4  박서은     여성  42.0   167.0            60.0         57.0    False     안 마심
#
#     Phone Number  Request Counselling Paid Plan      Joined At     Updated At  \
# 0  010-2292-6251                False       0개월  2016년 07월 05일  2016년 07월 05일
# 1    01045795881                False       0개월  2016년 10월 02일  2016년 11월 29일
# 2  010-7719-8346                False       0개월  2017년 09월 06일  2017년 09월 06일
# 3    01011947169                False       0개월  2017년 06월 02일  2017년 07월 28일
# 4  010-2575-6398                 True       0개월  2017년 05월 07일  2017년 05월 07일
#
#    Is Free  IsDrinking
# 0     True         1.0
# 1     True         1.0
# 2     True         1.0
# 3     True         0.0
# 4     True         0.0

# %%
users['Gender'].unique()
# Out:
# array(['남성', '여성', 'Male', 'female', 'male', '여', '남', 'Female', 'FEMALE',
#        'MALE'], dtype=object)

# %%
def replace_data(old, new):
    def _replace(data):
        if type(data) is str:
            for word in old:
                data = data.replace(word, new)
        return data
    return _replace

# %% [markdown]
# - MALE, FEMALE 때문에 male을 먼저 처리하면 문제가 된다.
# - 순서에 신경써야 하다니!
# - 다른 좋은 방법이 없을까?

# %%
users['Gender'] = users['Gender'].map(replace_data(['여성', '여', 'Female', 'FEMALE', ], 'female'))

# %%
users['Gender'] = users['Gender'].map(replace_data(['남성', '남', 'Male', 'MALE'], 'male'))

# %%
users['Gender'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
#users.to_csv('./data/USER_INFO_08.csv', index=False)

# %% [markdown]
# **17. 전체 인원이 아닌, 남성/여성 각각의 최소/평균/최대 키/몸무게/나이를 구해주세요.**
#
# 결과적으로 다음의 수치가 나와야 합니다.
#   * 전체 남성의 최소/평균/최대 나이
#   * 전체 남성의 최소/평균/최대 몸무게(kg)
#   * 전체 남성의 최소/평균/최대 키(cm)
#
#   * 전체 여성의 최소/평균/최대 나이
#   * 전체 여성의 최소/평균/최대 몸무게(kg)
#   * 전체 여성의 최소/평균/최대 키(cm)

# %%
#users = pd.read_csv('./data/USER_INFO_08.csv')

# %%
users.head()
# Out:
#   Name  Gender   Age  Height  Current Weight  Goal Weight  Smoking Drinking  \
# 0  안원준    male  31.0   176.0            78.0         68.0    False     주 1회
# 1  유세아  female  39.0   172.0            56.0         51.0     True     월 1회
# 2  송솔은  female   NaN   167.0             NaN          NaN     True     주 1회
# 3  백서원  female  36.0     NaN            67.0         65.0     True     안 마심
# 4  박서은  female  42.0   167.0            60.0         57.0    False     안 마심
#
#     Phone Number  Request Counselling Paid Plan      Joined At     Updated At  \
# 0  010-2292-6251                False       0개월  2016년 07월 05일  2016년 07월 05일
# 1    01045795881                False       0개월  2016년 10월 02일  2016년 11월 29일
# 2  010-7719-8346                False       0개월  2017년 09월 06일  2017년 09월 06일
# 3    01011947169                False       0개월  2017년 06월 02일  2017년 07월 28일
# 4  010-2575-6398                 True       0개월  2017년 05월 07일  2017년 05월 07일
#
#    Is Free  IsDrinking
# 0     True         1.0
# 1     True         1.0
# 2     True         1.0
# 3     True         0.0
# 4     True         0.0

# %%
users.loc[users['Gender']=='male'].head()
# Out:
#    Name Gender   Age  Height  Current Weight  Goal Weight  Smoking Drinking  \
# 0   안원준   male  31.0   176.0            78.0         68.0    False     주 1회
# 5   전재성   male  39.0   171.0            76.0         73.0    False     월 1회
# 7   허태연   male  32.0     NaN            83.0         78.0    False     월 2회
# 9   황윤일   male  29.0   171.0            76.0         70.0    False     월 1회
# 10  한대권   male  37.0     NaN            78.0         69.0    False     주 1회
#
#      Phone Number  Request Counselling Paid Plan      Joined At  \
# 0   010-2292-6251                False       0개월  2016년 07월 05일
# 5   010-7299-1288                False       3개월  2017년 12월 01일
# 7     01019249265                False       0개월  2016년 10월 25일
# 9     01036423916                False       3개월  2017년 11월 04일
# 10            NaN                False       3개월  2016년 04월 10일
#
#        Updated At  Is Free  IsDrinking
# 0   2016년 07월 05일     True         1.0
# 5   2018년 03월 05일    False         1.0
# 7   2016년 12월 01일     True         1.0
# 9   2017년 12월 11일    False         1.0
# 10  2016년 04월 10일    False         1.0

# %%
male_user = users.loc[users['Gender']=='male']

# %% [markdown]
# - 전체 남성의 최소/평균/최대 나이

# %%
male_user['Age'].min(), male_user['Age'].mean(), male_user['Age'].max()
# Out:
# (2.0, 34.94158337019018, 119.0)

# %% [markdown]
# - 전체 남성의 최소/평균/최대 몸무게(kg)

# %%
male_user['Current Weight'].min(), male_user['Current Weight'].mean(), male_user['Current Weight'].max()
# Out:
# (66.0, 80.0635944535773, 149.0)

# %% [markdown]
# - 전체 남성의 최소/평균/최대 키(cm)

# %%
male_user['Height'].min(), male_user['Height'].mean(), male_user['Height'].max()
# Out:
# (121.0, 175.36344078310444, 209.0)

# %% [markdown]
# - 전체 여성

# %%
female_user = users.loc[users['Gender']=='female'].head()

# %% [markdown]
# - 전체 여성의 최소/평균/최대 나이

# %%
female_user['Age'].min(), female_user['Age'].mean(), female_user['Age'].max()
# Out:
# (36.0, 39.0, 42.0)

# %% [markdown]
# - 전체 여성의 최소/평균/최대 몸무게(kg)

# %%
female_user['Current Weight'].min(), female_user['Current Weight'].mean(), female_user['Current Weight'].max()
# Out:
# (56.0, 61.0, 67.0)

# %% [markdown]
# - 전체 여성의 최소/평균/최대 키(cm)

# %%
female_user['Height'].min(), female_user['Height'].mean(), female_user['Height'].max()
# Out:
# (167.0, 170.75, 177.0)

# %% [markdown]
# ** 18. 감량 목표를 분석하기 **
#
# 데이터에서 '현재 체중' - '목표 체중' 을 하면 감량 목표가 나올 것입니다. 감량 목표를 찾아서 새로운 컬럼을 만들어주세요.
#
# 또한 kg별로 감량을 원하는 사람의 총 인원을 구해주세요. 가령 1) 1kg 감량을 원하는 총 인원, 2) 2kg 감량을 원하는 총 인원, ... 10) 10kg 감량을 원하는 총 인원이 나와야 합니다.

# %%
users.head()
# Out:
#   Name  Gender   Age  Height  Current Weight  Goal Weight  Smoking Drinking  \
# 0  안원준    male  31.0   176.0            78.0         68.0    False     주 1회
# 1  유세아  female  39.0   172.0            56.0         51.0     True     월 1회
# 2  송솔은  female   NaN   167.0             NaN          NaN     True     주 1회
# 3  백서원  female  36.0     NaN            67.0         65.0     True     안 마심
# 4  박서은  female  42.0   167.0            60.0         57.0    False     안 마심
#
#     Phone Number  Request Counselling Paid Plan      Joined At     Updated At  \
# 0  010-2292-6251                False       0개월  2016년 07월 05일  2016년 07월 05일
# 1    01045795881                False       0개월  2016년 10월 02일  2016년 11월 29일
# 2  010-7719-8346                False       0개월  2017년 09월 06일  2017년 09월 06일
# 3    01011947169                False       0개월  2017년 06월 02일  2017년 07월 28일
# 4  010-2575-6398                 True       0개월  2017년 05월 07일  2017년 05월 07일
#
#    Is Free  IsDrinking
# 0     True         1.0
# 1     True         1.0
# 2     True         1.0
# 3     True         0.0
# 4     True         0.0

# %%
users['Loss Goal'] = users['Current Weight'] - users['Goal Weight']

# %%
users.head()
# Out:
#   Name  Gender   Age  Height  Current Weight  Goal Weight  Smoking Drinking  \
# 0  안원준    male  31.0   176.0            78.0         68.0    False     주 1회
# 1  유세아  female  39.0   172.0            56.0         51.0     True     월 1회
# 2  송솔은  female   NaN   167.0             NaN          NaN     True     주 1회
# 3  백서원  female  36.0     NaN            67.0         65.0     True     안 마심
# 4  박서은  female  42.0   167.0            60.0         57.0    False     안 마심
#
#     Phone Number  Request Counselling Paid Plan      Joined At     Updated At  \
# 0  010-2292-6251                False       0개월  2016년 07월 05일  2016년 07월 05일
# 1    01045795881                False       0개월  2016년 10월 02일  2016년 11월 29일
# 2  010-7719-8346                False       0개월  2017년 09월 06일  2017년 09월 06일
# 3    01011947169                False       0개월  2017년 06월 02일  2017년 07월 28일
# 4  010-2575-6398                 True       0개월  2017년 05월 07일  2017년 05월 07일
#
#    Is Free  IsDrinking  Loss Goal
# 0     True         1.0       10.0
# 1     True         1.0        5.0
# 2     True         1.0        NaN
# 3     True         0.0        2.0
# 4     True         0.0        3.0

# %%
users['Loss Goal'].value_counts().sort_index()
# Out:
# 1.0     9508
# 2.0     9500
# 3.0     9494
# 4.0     9529
# 5.0     9629
# 6.0     9754
# 7.0     9443
# 8.0     9397
# 9.0     9629
# 10.0    9351
# Name: Loss Goal, dtype: int64

# %%
#users.to_csv('./data/USER_INFO_09.csv', index=False)

# %% [markdown]
# ** 19. '가입 개월 수'를 숫자로 표현하기 **
#
# '가입 개월 수' 컬럼을 숫자로 정리해주세요. 현재 3개월, 6개월, 12개월로 되어있는데, 이를 3, 6, 12로 정리하시면 됩니다.
#
# 또한 0개월은 0이 아닌 NaN으로 집어넣어 주세요.

# %%
#users = pd.read_csv('./data/USER_INFO_09.csv')

# %%
users.head()
# Out:
#   Name  Gender   Age  Height  Current Weight  Goal Weight  Smoking Drinking  \
# 0  안원준    male  31.0   176.0            78.0         68.0    False     주 1회
# 1  유세아  female  39.0   172.0            56.0         51.0     True     월 1회
# 2  송솔은  female   NaN   167.0             NaN          NaN     True     주 1회
# 3  백서원  female  36.0     NaN            67.0         65.0     True     안 마심
# 4  박서은  female  42.0   167.0            60.0         57.0    False     안 마심
#
#     Phone Number  Request Counselling Paid Plan      Joined At     Updated At  \
# 0  010-2292-6251                False       0개월  2016년 07월 05일  2016년 07월 05일
# 1    01045795881                False       0개월  2016년 10월 02일  2016년 11월 29일
# 2  010-7719-8346                False       0개월  2017년 09월 06일  2017년 09월 06일
# 3    01011947169                False       0개월  2017년 06월 02일  2017년 07월 28일
# 4  010-2575-6398                 True       0개월  2017년 05월 07일  2017년 05월 07일
#
#    Is Free  IsDrinking  Loss Goal
# 0     True         1.0       10.0
# 1     True         1.0        5.0
# 2     True         1.0        NaN
# 3     True         0.0        2.0
# 4     True         0.0        3.0

# %%
# 수치 col에 불필요한 데이터를 제거하거나 변경한다.
def clean_num_col(old, new):
    def wrapper(data):
        if type(data) is str:
            num = data.replace(old, new)
            return int(num)
        return data
    return wrapper

# %%
clean_paid_plan = clean_num_col('개월', '')

# %%
users['Paid Plan'] = users['Paid Plan'].map(clean_paid_plan)

# %%
users['Paid Plan'].value_counts()
# Out:
# 0     74955
# 3     21250
# 6      7291
# 12     3343
# Name: Paid Plan, dtype: int64

# %%
users.loc[users['Paid Plan'] == 0, 'Paid Plan'] = np.nan

# %%
users['Paid Plan'].value_counts()
# Out:
# 3.0     21250
# 6.0      7291
# 12.0     3343
# Name: Paid Plan, dtype: int64

# %%
users['Paid Plan'].unique()
# Out:
# array([nan,  3., 12.,  6.])

# %%
#users.to_csv('./data/USER_INFO_10.csv', index=False)

# %% [markdown]
# ** 20. '음주 여부'를 숫자로 표현하기**
#
# '음주 여부' 컬럼을 숫자로 정리해주세요. 현재 1) 주 2회, 2) 주 1회, 3) 월 2회, 4) 월 1회 5) 안 마심으로 되어 있습니다만, 이를 월 기준 음주 횟수로 통일해주세요. 여기서 월은 30일로, 주는 4주로 고정합니다.
#
# 가령 1) 주 2회는 8, 2) 주 1회는 4, 3) 월 2회는 2, 4) 월 1회는 1, 5) 안 마심은 0으로 표현하면 됩니다.

# %%
#users = pd.read_csv('./data/USER_INFO_10.csv')

# %%
users.head()
# Out:
#   Name  Gender   Age  Height  Current Weight  Goal Weight  Smoking Drinking  \
# 0  안원준    male  31.0   176.0            78.0         68.0    False     주 1회
# 1  유세아  female  39.0   172.0            56.0         51.0     True     월 1회
# 2  송솔은  female   NaN   167.0             NaN          NaN     True     주 1회
# 3  백서원  female  36.0     NaN            67.0         65.0     True     안 마심
# 4  박서은  female  42.0   167.0            60.0         57.0    False     안 마심
#
#     Phone Number  Request Counselling  Paid Plan      Joined At  \
# 0  010-2292-6251                False        NaN  2016년 07월 05일
# 1    01045795881                False        NaN  2016년 10월 02일
# 2  010-7719-8346                False        NaN  2017년 09월 06일
# 3    01011947169                False        NaN  2017년 06월 02일
# 4  010-2575-6398                 True        NaN  2017년 05월 07일
#
#       Updated At  Is Free  IsDrinking  Loss Goal
# 0  2016년 07월 05일     True         1.0       10.0
# 1  2016년 11월 29일     True         1.0        5.0
# 2  2017년 09월 06일     True         1.0        NaN
# 3  2017년 07월 28일     True         0.0        2.0
# 4  2017년 05월 07일     True         0.0        3.0

# %%
users['Drinking'].unique()
# Out:
# array(['주 1회', '월 1회', '안 마심', '월 2회', '주 2회'], dtype=object)

# %%
def drinking_count(data):
    if data == '주 2회':
        return 8
    elif data == '주 1회':
        return 4
    elif data == '월 2회':
        return 2
    elif data == '월 1회':
        return 1
    return np.nan

# %%
users['Drinking'] = users['Drinking'].map(drinking_count)

# %%
users['Drinking'].unique()
# Out:
# array([ 4.,  1., nan,  2.,  8.])

# %%
#users.to_csv('./data/USER_INFO_11.csv', index=False)

# %% [markdown]
# ## 과제(고급)

# %% [markdown]
# ** 21.휴대폰 번호 정리하기 **
#
# 다양한 표현으로 되어있는 휴대폰 번호를 010-xxxx-xxxx 로 통일해주세요. 가령 휴대폰 번호에 하이픈이 없으면 넣어주시면 됩니다.
#
# 또한 unknown으로 되어있거나 비어있는 값은 NaN으로 처리해주세요.

# %%
#users = pd.read_csv('./data/USER_INFO_11.csv')

# %%
str_sample = '010-1234-1234'.replace('-', '')

# %%
str_sample
# Out:
# '01012341234'

# %%
f'{str_sample[:3]}-{str_sample[3:7]}-{str_sample[7:]}'
# Out:
# '010-1234-1234'

# %%
import re
reg_phone_num = re.compile('\d{11}')

# %%
result = reg_phone_num.match(str_sample)
result.group()
# Out:
# '01012341234'

# %%
users.head()
# Out:
#   Name  Gender   Age  Height  Current Weight  Goal Weight  Smoking  Drinking  \
# 0  안원준    male  31.0   176.0            78.0         68.0    False       4.0
# 1  유세아  female  39.0   172.0            56.0         51.0     True       1.0
# 2  송솔은  female   NaN   167.0             NaN          NaN     True       4.0
# 3  백서원  female  36.0     NaN            67.0         65.0     True       NaN
# 4  박서은  female  42.0   167.0            60.0         57.0    False       NaN
#
#     Phone Number  Request Counselling  Paid Plan      Joined At  \
# 0  010-2292-6251                False        NaN  2016년 07월 05일
# 1    01045795881                False        NaN  2016년 10월 02일
# 2  010-7719-8346                False        NaN  2017년 09월 06일
# 3    01011947169                False        NaN  2017년 06월 02일
# 4  010-2575-6398                 True        NaN  2017년 05월 07일
#
#       Updated At  Is Free  IsDrinking  Loss Goal
# 0  2016년 07월 05일     True         1.0       10.0
# 1  2016년 11월 29일     True         1.0        5.0
# 2  2017년 09월 06일     True         1.0        NaN
# 3  2017년 07월 28일     True         0.0        2.0
# 4  2017년 05월 07일     True         0.0        3.0

# %%
(users['Phone Number'] == 'unknown').sum()
# Out:
# 0

# %%
def clean_phone_number(data):
    if type(data) is str:
        result = reg_phone_num.match(data)
        if result is None:
            return np.nan
        else:
            result.group()
    return data

# %%
def format_phone_number(data):
    if type(data) is str:
        return f'{data[:3]}-{data[3:7]}-{data[7:]}'
    return data

# %%
users['Phone Number'] = users['Phone Number'].map(replace_data('-', ''))\
                                             .map(clean_phone_number)\
                                             .map(format_phone_number)

# %%
users['Phone Number'].head()
# Out:
# 0    010-2292-6251
# 1    010-4579-5881
# 2    010-7719-8346
# 3    010-1194-7169
# 4    010-2575-6398
# Name: Phone Number, dtype: object

# %%
#users.to_csv('./data/USER_INFO_12.csv', index=False)

# %% [markdown]
# ** 22. 날짜를 사용 가능하게 정리하기 **
#
# 현재 '회원 가입일' 컬럼과 '회원 정보 갱신일' 컬럼은 20xx년 xx월 xx일 과 같은 형식으로 되어있습니다.
#
# 이 데이터를 현재 판다스에서는 날짜 컬럼이 아닌 문자열(텍스트) 컬럼으로 인식하고 있는데, 이 컬럼을 날짜 컬럼으로 인식할 수 있도록 수정해주세요.

# %%
#users = pd.read_csv('./data/USER_INFO_12.csv')

# %%
from datetime import datetime
import re

# %%
p = re.compile(r'\d+')

# %%
sample_date1 = '2018년 7월 13일'

# %%
p.findall(sample_date1)
# Out:
# ['2018', '7', '13']

# %%
'-'.join(p.findall(sample_date1))
# Out:
# '2018-7-13'

# %%
pd.to_datetime('-'.join(p.findall(sample_date1)))
# Out:
# Timestamp('2018-07-13 00:00:00')

# %%
sample_date2 = '2018년 07월 03일'

# %%
pd.to_datetime('-'.join(p.findall(sample_date2)))
# Out:
# Timestamp('2018-07-03 00:00:00')

# %%
users.head()
# Out:
#   Name  Gender   Age  Height  Current Weight  Goal Weight  Smoking  Drinking  \
# 0  안원준    male  31.0   176.0            78.0         68.0    False       4.0
# 1  유세아  female  39.0   172.0            56.0         51.0     True       1.0
# 2  송솔은  female   NaN   167.0             NaN          NaN     True       4.0
# 3  백서원  female  36.0     NaN            67.0         65.0     True       NaN
# 4  박서은  female  42.0   167.0            60.0         57.0    False       NaN
#
#     Phone Number  Request Counselling  Paid Plan      Joined At  \
# 0  010-2292-6251                False        NaN  2016년 07월 05일
# 1  010-4579-5881                False        NaN  2016년 10월 02일
# 2  010-7719-8346                False        NaN  2017년 09월 06일
# 3  010-1194-7169                False        NaN  2017년 06월 02일
# 4  010-2575-6398                 True        NaN  2017년 05월 07일
#
#       Updated At  Is Free  IsDrinking  Loss Goal
# 0  2016년 07월 05일     True         1.0       10.0
# 1  2016년 11월 29일     True         1.0        5.0
# 2  2017년 09월 06일     True         1.0        NaN
# 3  2017년 07월 28일     True         0.0        2.0
# 4  2017년 05월 07일     True         0.0        3.0

# %%
users['Joined At'].isnull().sum()
# Out:
# 0

# %%
users['Joined At'].describe()
# Out:
# count            106839
# unique              731
# top       2016년 05월 19일
# freq                182
# Name: Joined At, dtype: object

# %%
users['Joined At'].head()
# Out:
# 0    2016년 07월 05일
# 1    2016년 10월 02일
# 2    2017년 09월 06일
# 3    2017년 06월 02일
# 4    2017년 05월 07일
# Name: Joined At, dtype: object

# %%
def clean_date(data):
    if type(data) is str:
        return pd.to_datetime('-'.join(p.findall(data)))
    return data

# %%
users['Joined At'] = users['Joined At'].map(clean_date)

# %%
users['Joined At'].head()
# Out:
# 0   2016-07-05
# 1   2016-10-02
# 2   2017-09-06
# 3   2017-06-02
# 4   2017-05-07
# Name: Joined At, dtype: datetime64[ns]

# %%
users['Updated At'] = users['Updated At'].map(clean_date)

# %%
users['Updated At'].head()
# Out:
# 0   2016-07-05
# 1   2016-11-29
# 2   2017-09-06
# 3   2017-07-28
# 4   2017-05-07
# Name: Updated At, dtype: datetime64[ns]

# %%
#users.to_csv('./data/USER_INFO_13.csv', index=False)

# %% [markdown]
# ** 23. 날짜를 기준으로 분석하기 **
#
# 22번에서 날짜 컬럼을 만들었으면 다음을 분석해주세요.
#
# 1. 월별 전체 회원 가입량
# 2. 월 별 유료/무료 회원 가입량의 차이
# 3. 월 별 남성/여성 회원 가입량의 차이

# %%
users.head()
# Out:
#   Name  Gender   Age  Height  Current Weight  Goal Weight  Smoking  Drinking  \
# 0  안원준    male  31.0   176.0            78.0         68.0    False       4.0
# 1  유세아  female  39.0   172.0            56.0         51.0     True       1.0
# 2  송솔은  female   NaN   167.0             NaN          NaN     True       4.0
# 3  백서원  female  36.0     NaN            67.0         65.0     True       NaN
# 4  박서은  female  42.0   167.0            60.0         57.0    False       NaN
#
#     Phone Number  Request Counselling  Paid Plan  Joined At Updated At  \
# 0  010-2292-6251                False        NaN 2016-07-05 2016-07-05
# 1  010-4579-5881                False        NaN 2016-10-02 2016-11-29
# 2  010-7719-8346                False        NaN 2017-09-06 2017-09-06
# 3  010-1194-7169                False        NaN 2017-06-02 2017-07-28
# 4  010-2575-6398                 True        NaN 2017-05-07 2017-05-07
#
#    Is Free  IsDrinking  Loss Goal
# 0     True         1.0       10.0
# 1     True         1.0        5.0
# 2     True         1.0        NaN
# 3     True         0.0        2.0
# 4     True         0.0        3.0

# %%
users['Joined At'].describe()
# Out:
# count                  106839
# unique                    731
# top       2016-05-19 00:00:00
# freq                      182
# first     2016-01-01 00:00:00
# last      2017-12-31 00:00:00
# Name: Joined At, dtype: object

# %%
user_joined = users.resample('M', on='Joined At')

# %%
user_joined.size()
# Out:
# Joined At
# 2016-01-31    4407
# 2016-02-29    4242
# 2016-03-31    4434
# 2016-04-30    4427
# 2016-05-31    4604
# 2016-06-30    4390
# 2016-07-31    4606
# 2016-08-31    4497
# 2016-09-30    4507
# 2016-10-31    4516
# 2016-11-30    4411
# 2016-12-31    4568
# 2017-01-31    4557
# 2017-02-28    4063
# 2017-03-31    4551
# 2017-04-30    4370
# 2017-05-31    4473
# 2017-06-30    4403
# 2017-07-31    4473
# 2017-08-31    4586
# 2017-09-30    4293
# 2017-10-31    4478
# 2017-11-30    4359
# 2017-12-31    4624
# Freq: M, dtype: int64

# %%
paid_user = users[users['Is Free']==True].resample('M', on='Joined At')

# %%
paid_user.size()
# Out:
# Joined At
# 2016-01-31    3048
# 2016-02-29    2972
# 2016-03-31    3081
# 2016-04-30    3109
# 2016-05-31    3238
# 2016-06-30    3031
# 2016-07-31    3258
# 2016-08-31    3141
# 2016-09-30    3134
# 2016-10-31    3160
# 2016-11-30    3115
# 2016-12-31    3206
# 2017-01-31    3182
# 2017-02-28    2828
# 2017-03-31    3188
# 2017-04-30    3078
# 2017-05-31    3173
# 2017-06-30    3078
# 2017-07-31    3141
# 2017-08-31    3205
# 2017-09-30    3066
# 2017-10-31    3209
# 2017-11-30    3041
# 2017-12-31    3273
# Freq: M, dtype: int64

# %%
free_user = users[users['Is Free']==False].resample('M', on='Joined At')

# %%
free_user.size()
# Out:
# Joined At
# 2016-01-31    1359
# 2016-02-29    1270
# 2016-03-31    1353
# 2016-04-30    1318
# 2016-05-31    1366
# 2016-06-30    1359
# 2016-07-31    1348
# 2016-08-31    1356
# 2016-09-30    1373
# 2016-10-31    1356
# 2016-11-30    1296
# 2016-12-31    1362
# 2017-01-31    1375
# 2017-02-28    1235
# 2017-03-31    1363
# 2017-04-30    1292
# 2017-05-31    1300
# 2017-06-30    1325
# 2017-07-31    1332
# 2017-08-31    1381
# 2017-09-30    1227
# 2017-10-31    1269
# 2017-11-30    1318
# 2017-12-31    1351
# Freq: M, dtype: int64

# %%
male_user = users[users['Gender']=='male'].resample('M', on='Joined At')

# %%
male_user.size()
# Out:
# Joined At
# 2016-01-31    2598
# 2016-02-29    2472
# 2016-03-31    2534
# 2016-04-30    2615
# 2016-05-31    2688
# 2016-06-30    2596
# 2016-07-31    2714
# 2016-08-31    2593
# 2016-09-30    2664
# 2016-10-31    2628
# 2016-11-30    2603
# 2016-12-31    2714
# 2017-01-31    2691
# 2017-02-28    2379
# 2017-03-31    2717
# 2017-04-30    2605
# 2017-05-31    2654
# 2017-06-30    2600
# 2017-07-31    2637
# 2017-08-31    2669
# 2017-09-30    2461
# 2017-10-31    2610
# 2017-11-30    2549
# 2017-12-31    2763
# Freq: M, dtype: int64

# %%
female_user = users[users['Gender']=='female'].resample('M', on='Joined At')

# %%
female_user.size()
# Out:
# Joined At
# 2016-01-31    1809
# 2016-02-29    1770
# 2016-03-31    1900
# 2016-04-30    1812
# 2016-05-31    1916
# 2016-06-30    1794
# 2016-07-31    1892
# 2016-08-31    1904
# 2016-09-30    1843
# 2016-10-31    1888
# 2016-11-30    1808
# 2016-12-31    1854
# 2017-01-31    1866
# 2017-02-28    1684
# 2017-03-31    1834
# 2017-04-30    1765
# 2017-05-31    1819
# 2017-06-30    1803
# 2017-07-31    1836
# 2017-08-31    1917
# 2017-09-30    1832
# 2017-10-31    1868
# 2017-11-30    1810
# 2017-12-31    1861
# Freq: M, dtype: int64

# %% [markdown]
# ** 24. 회원 정보가 맞는지 여부를 확인하는 컬럼을 만들기 **
#
# 더 정확한 데이터 분석을 위해서는, 현재까지 고객님이 기업한 회원 정보가 정확한지를 확인하는 작업이 필요합니다. 분석팀에서 데이터를 다음과 같이 정리하면, 오퍼레이션 팀과 코칭 팀이 협업을 통해서 고객 정보를 개선하고, 더 좋은 서비스를 제공할 수 있을 것 같습니다. 다음의 내용이 담겨있는 새로운 컬럼을 하나 만들어주세요. 해당 컬럼에는 reject / counselling / duplicated / confirmed 라는 결과값이 들어가야 합니다.
#
# 다음의 경우에는 재기입을 요청한다. (reject)
# * 전화번호가 비어있는 경우
#
# 다음의 경우는 트레이너와 상담을 유도한다. (counselling)
# * 상담 요청(counselling)이 True인 사람.
#
# 다음의 경우에는 중복을 확인한다. (duplicated)
# * 동일한 이름에 동일한 전화번호를 찾아낸다. 이는 중복되었다고 가정한다.
#
# 나머지는 문제가 없다. (confirmed)

# %%
users.head()
# Out:
#   Name  Gender   Age  Height  Current Weight  Goal Weight  Smoking  Drinking  \
# 0  안원준    male  31.0   176.0            78.0         68.0    False       4.0
# 1  유세아  female  39.0   172.0            56.0         51.0     True       1.0
# 2  송솔은  female   NaN   167.0             NaN          NaN     True       4.0
# 3  백서원  female  36.0     NaN            67.0         65.0     True       NaN
# 4  박서은  female  42.0   167.0            60.0         57.0    False       NaN
#
#     Phone Number  Request Counselling  Paid Plan  Joined At Updated At  \
# 0  010-2292-6251                False        NaN 2016-07-05 2016-07-05
# 1  010-4579-5881                False        NaN 2016-10-02 2016-11-29
# 2  010-7719-8346                False        NaN 2017-09-06 2017-09-06
# 3  010-1194-7169                False        NaN 2017-06-02 2017-07-28
# 4  010-2575-6398                 True        NaN 2017-05-07 2017-05-07
#
#    Is Free  IsDrinking  Loss Goal
# 0     True         1.0       10.0
# 1     True         1.0        5.0
# 2     True         1.0        NaN
# 3     True         0.0        2.0
# 4     True         0.0        3.0

# %%
users['To Do'] = ''

# %%
users.loc[users['Phone Number'].isnull(), 'To Do'] = 'reject'

# %%
users.head()
# Out:
#   Name  Gender   Age  Height  Current Weight  Goal Weight  Smoking  Drinking  \
# 0  안원준    male  31.0   176.0            78.0         68.0    False       4.0
# 1  유세아  female  39.0   172.0            56.0         51.0     True       1.0
# 2  송솔은  female   NaN   167.0             NaN          NaN     True       4.0
# 3  백서원  female  36.0     NaN            67.0         65.0     True       NaN
# 4  박서은  female  42.0   167.0            60.0         57.0    False       NaN
#
#     Phone Number  Request Counselling  Paid Plan  Joined At Updated At  \
# 0  010-2292-6251                False        NaN 2016-07-05 2016-07-05
# 1  010-4579-5881                False        NaN 2016-10-02 2016-11-29
# 2  010-7719-8346                False        NaN 2017-09-06 2017-09-06
# 3  010-1194-7169                False        NaN 2017-06-02 2017-07-28
# 4  010-2575-6398                 True        NaN 2017-05-07 2017-05-07
#
#    Is Free  IsDrinking  Loss Goal To Do
# 0     True         1.0       10.0
# 1     True         1.0        5.0
# 2     True         1.0        NaN
# 3     True         0.0        2.0
# 4     True         0.0        3.0

# %%
users.loc[users['Request Counselling'], 'To Do'] = 'counselling'

# %%
users.head()
# Out:
#   Name  Gender   Age  Height  Current Weight  Goal Weight  Smoking  Drinking  \
# 0  안원준    male  31.0   176.0            78.0         68.0    False       4.0
# 1  유세아  female  39.0   172.0            56.0         51.0     True       1.0
# 2  송솔은  female   NaN   167.0             NaN          NaN     True       4.0
# 3  백서원  female  36.0     NaN            67.0         65.0     True       NaN
# 4  박서은  female  42.0   167.0            60.0         57.0    False       NaN
#
#     Phone Number  Request Counselling  Paid Plan  Joined At Updated At  \
# 0  010-2292-6251                False        NaN 2016-07-05 2016-07-05
# 1  010-4579-5881                False        NaN 2016-10-02 2016-11-29
# 2  010-7719-8346                False        NaN 2017-09-06 2017-09-06
# 3  010-1194-7169                False        NaN 2017-06-02 2017-07-28
# 4  010-2575-6398                 True        NaN 2017-05-07 2017-05-07
#
#    Is Free  IsDrinking  Loss Goal        To Do
# 0     True         1.0       10.0
# 1     True         1.0        5.0
# 2     True         1.0        NaN
# 3     True         0.0        2.0
# 4     True         0.0        3.0  counselling

# %%
users.loc[users.duplicated(['Name', 'Phone Number']), 'To Do'] = 'duplicated'

# %%
users.head()
# Out:
#   Name  Gender   Age  Height  Current Weight  Goal Weight  Smoking  Drinking  \
# 0  안원준    male  31.0   176.0            78.0         68.0    False       4.0
# 1  유세아  female  39.0   172.0            56.0         51.0     True       1.0
# 2  송솔은  female   NaN   167.0             NaN          NaN     True       4.0
# 3  백서원  female  36.0     NaN            67.0         65.0     True       NaN
# 4  박서은  female  42.0   167.0            60.0         57.0    False       NaN
#
#     Phone Number  Request Counselling  Paid Plan  Joined At Updated At  \
# 0  010-2292-6251                False        NaN 2016-07-05 2016-07-05
# 1  010-4579-5881                False        NaN 2016-10-02 2016-11-29
# 2  010-7719-8346                False        NaN 2017-09-06 2017-09-06
# 3  010-1194-7169                False        NaN 2017-06-02 2017-07-28
# 4  010-2575-6398                 True        NaN 2017-05-07 2017-05-07
#
#    Is Free  IsDrinking  Loss Goal        To Do
# 0     True         1.0       10.0
# 1     True         1.0        5.0
# 2     True         1.0        NaN
# 3     True         0.0        2.0
# 4     True         0.0        3.0  counselling

# %%
users[users['To Do'] == 'duplicated'].head()
# Out:
#      Name  Gender   Age  Height  Current Weight  Goal Weight  Smoking  \
# 575   조서후    male  41.0   159.0            76.0         66.0    False
# 1479  조지희  female  32.0   167.0            59.0         53.0     True
# 1651  문시빈    male  42.0   177.0            88.0         82.0     True
# 2169  최서빈  female  29.0   169.0            61.0         57.0    False
# 2207  류세현  female  26.0     NaN            55.0         45.0    False
#
#       Drinking Phone Number  Request Counselling  Paid Plan  Joined At  \
# 575        1.0          NaN                False        3.0 2017-11-03
# 1479       2.0          NaN                False        NaN 2017-09-27
# 1651       1.0          NaN                 True        NaN 2017-09-26
# 2169       2.0          NaN                False        NaN 2017-08-26
# 2207       8.0          NaN                False        NaN 2016-05-16
#
#      Updated At  Is Free  IsDrinking  Loss Goal       To Do
# 575  2017-11-03    False         1.0       10.0  duplicated
# 1479 2017-12-25     True         1.0        6.0  duplicated
# 1651 2017-12-10     True         1.0        6.0  duplicated
# 2169 2017-12-02     True         1.0        4.0  duplicated
# 2207 2016-05-16     True         1.0       10.0  duplicated

# %%
users[users['Name'] == '김영재']
# Out:
#        Name Gender   Age  Height  Current Weight  Goal Weight  Smoking  \
# 2473    김영재   male  34.0     NaN            77.0         74.0     True
# 15061   김영재   male  27.0   168.0            83.0         76.0     True
# 20733   김영재   male  34.0     NaN            74.0         69.0    False
# 25273   김영재   male  34.0   176.0            73.0         69.0     True
# 28241   김영재   male  39.0   170.0            79.0         78.0    False
# 29637   김영재   male   NaN   177.0            78.0         71.0    False
# 34101   김영재   male  31.0   163.0            80.0         76.0     True
# 52695   김영재   male  30.0   170.0            77.0         67.0    False
# 65833   김영재   male  30.0   174.0             NaN          NaN    False
# 70062   김영재   male  37.0   173.0            82.0         80.0    False
# 72589   김영재   male  36.0   173.0            76.0         70.0    False
# 81810   김영재   male  26.0   173.0            82.0         75.0    False
# 106829  김영재   male  34.0     NaN            77.0         74.0     True
#
#         Drinking   Phone Number  Request Counselling  Paid Plan  Joined At  \
# 2473         1.0  010-5313-4126                 True        3.0 2016-09-16
# 15061        2.0  010-6838-5472                False        NaN 2017-12-30
# 20733        2.0  010-5663-2525                False        NaN 2017-07-26
# 25273        2.0  010-5493-4518                False        NaN 2017-04-27
# 28241        2.0  010-9744-5151                False        NaN 2017-09-08
# 29637        4.0  010-6788-3448                False        NaN 2017-03-06
# 34101        2.0  010-5129-2793                False        NaN 2016-09-16
# 52695        1.0  010-8519-5137                False        NaN 2016-07-24
# 65833        4.0  010-3396-4246                False        3.0 2016-10-09
# 70062        2.0  010-6669-4455                 True        NaN 2017-01-21
# 72589        8.0  010-4218-3534                False        NaN 2017-08-23
# 81810        1.0  010-8241-1882                False        3.0 2016-06-28
# 106829       1.0  010-5313-4126                 True        3.0 2016-09-16
#
#        Updated At  Is Free  IsDrinking  Loss Goal        To Do
# 2473   2016-11-29    False         1.0        3.0  counselling
# 15061  2017-12-30     True         1.0        7.0
# 20733  2017-07-26     True         1.0        5.0
# 25273  2017-04-27     True         1.0        4.0
# 28241  2017-12-09     True         1.0        1.0
# 29637  2017-04-30     True         1.0        7.0
# 34101  2016-09-16     True         1.0        4.0
# 52695  2016-07-24     True         1.0       10.0
# 65833  2016-10-09    False         1.0        NaN
# 70062  2017-01-21     True         1.0        2.0  counselling
# 72589  2017-08-23     True         1.0        6.0
# 81810  2016-06-28    False         1.0        7.0
# 106829 2016-11-29    False         1.0        3.0   duplicated

# %%
users.loc[users['To Do'] == '', 'To Do'] = 'confirmed'

# %%
users.head()
# Out:
#   Name  Gender   Age  Height  Current Weight  Goal Weight  Smoking  Drinking  \
# 0  안원준    male  31.0   176.0            78.0         68.0    False       4.0
# 1  유세아  female  39.0   172.0            56.0         51.0     True       1.0
# 2  송솔은  female   NaN   167.0             NaN          NaN     True       4.0
# 3  백서원  female  36.0     NaN            67.0         65.0     True       NaN
# 4  박서은  female  42.0   167.0            60.0         57.0    False       NaN
#
#     Phone Number  Request Counselling  Paid Plan  Joined At Updated At  \
# 0  010-2292-6251                False        NaN 2016-07-05 2016-07-05
# 1  010-4579-5881                False        NaN 2016-10-02 2016-11-29
# 2  010-7719-8346                False        NaN 2017-09-06 2017-09-06
# 3  010-1194-7169                False        NaN 2017-06-02 2017-07-28
# 4  010-2575-6398                 True        NaN 2017-05-07 2017-05-07
#
#    Is Free  IsDrinking  Loss Goal        To Do
# 0     True         1.0       10.0    confirmed
# 1     True         1.0        5.0    confirmed
# 2     True         1.0        NaN    confirmed
# 3     True         0.0        2.0    confirmed
# 4     True         0.0        3.0  counselling

# %% [markdown]
# **25. VIP 찾아내기**
#
# 다음의 고객을 특별 관리 대상으로 지정합니다. 특별 관리 대상이라고 함은, TKX 서비스의 VIP 플랜을 구매할 확률이 높은 분들을 의미합니다.
#
# 1. 트레이너와 상담을 요청한 사람. (counselling)
# 2. 상담을 요청하지 않은 사람 중, (현재 체중 - 목표 체중) 이 가장 높은 상위 1,000 명.
#
# 이 사람들을 특별관리 대상으로 지정하며, VIP라는 이름의 컬럼에 True 값을 넣으면 됩니다. 이후에는 오퍼레이션/코치 팀이 해당 고객님을 개별 컨택하여, 적극적으로 VIP 플랜을 구매하실 수 있도록 노력할 생각입니다. (특별관리 대상이 아닌 분들은 VIP 컬럼에 False 값을 넣으면 됩니다)
#
# 또한 전체 데이터와는 별개로, VIP 고객들만을 따로 뽑아내서 CSV파일로 저장할 수 있다면 좋겠습니다.

# %%
users.head()
# Out:
#   Name  Gender   Age  Height  Current Weight  Goal Weight  Smoking  Drinking  \
# 0  안원준    male  31.0   176.0            78.0         68.0    False       4.0
# 1  유세아  female  39.0   172.0            56.0         51.0     True       1.0
# 2  송솔은  female   NaN   167.0             NaN          NaN     True       4.0
# 3  백서원  female  36.0     NaN            67.0         65.0     True       NaN
# 4  박서은  female  42.0   167.0            60.0         57.0    False       NaN
#
#     Phone Number  Request Counselling  Paid Plan  Joined At Updated At  \
# 0  010-2292-6251                False        NaN 2016-07-05 2016-07-05
# 1  010-4579-5881                False        NaN 2016-10-02 2016-11-29
# 2  010-7719-8346                False        NaN 2017-09-06 2017-09-06
# 3  010-1194-7169                False        NaN 2017-06-02 2017-07-28
# 4  010-2575-6398                 True        NaN 2017-05-07 2017-05-07
#
#    Is Free  IsDrinking  Loss Goal        To Do
# 0     True         1.0       10.0    confirmed
# 1     True         1.0        5.0    confirmed
# 2     True         1.0        NaN    confirmed
# 3     True         0.0        2.0    confirmed
# 4     True         0.0        3.0  counselling

# %%
users['VIP'] = False

# %%
users.loc[users['To Do'] == 'counselling', 'VIP'] = True

# %%
users.head()
# Out:
#   Name  Gender   Age  Height  Current Weight  Goal Weight  Smoking  Drinking  \
# 0  안원준    male  31.0   176.0            78.0         68.0    False       4.0
# 1  유세아  female  39.0   172.0            56.0         51.0     True       1.0
# 2  송솔은  female   NaN   167.0             NaN          NaN     True       4.0
# 3  백서원  female  36.0     NaN            67.0         65.0     True       NaN
# 4  박서은  female  42.0   167.0            60.0         57.0    False       NaN
#
#     Phone Number  Request Counselling  Paid Plan  Joined At Updated At  \
# 0  010-2292-6251                False        NaN 2016-07-05 2016-07-05
# 1  010-4579-5881                False        NaN 2016-10-02 2016-11-29
# 2  010-7719-8346                False        NaN 2017-09-06 2017-09-06
# 3  010-1194-7169                False        NaN 2017-06-02 2017-07-28
# 4  010-2575-6398                 True        NaN 2017-05-07 2017-05-07
#
#    Is Free  IsDrinking  Loss Goal        To Do    VIP
# 0     True         1.0       10.0    confirmed  False
# 1     True         1.0        5.0    confirmed  False
# 2     True         1.0        NaN    confirmed  False
# 3     True         0.0        2.0    confirmed  False
# 4     True         0.0        3.0  counselling   True

# %%
users[users['Loss Goal']==10].loc[users['To Do']!='counselling'].shape
# Out:
# (8463, 18)

# %%
users[users['To Do'] != 'counselling'].sort_values(['Loss Goal', 'Current Weight'], ascending=False).head(1000)
# Out:
#           Name  Gender   Age  Height  Current Weight  Goal Weight  Smoking  \
# 63964      임장훈    male  34.0   181.0           149.0        139.0    False
# 72421      장초은  female  35.0   168.0           149.0        139.0    False
# 75204      송수정  female  34.0   176.0           149.0        139.0    False
# 105948     최유준    male  30.0   176.0           149.0        139.0    False
# 2650       황재호    male  37.0   177.0           148.0        138.0    False
# 9295       조영후    male  29.0   180.0           147.0        137.0     True
# 17178      양인태    male  36.0   171.0           147.0        137.0    False
# 43658      송서준    male  25.0   175.0           147.0        137.0    False
# 51678      조시훈    male  33.0   177.0           147.0        137.0    False
# 80402      손동은    male  35.0   176.0           147.0        137.0     True
# 84371      손동은    male  35.0   176.0           147.0        137.0     True
# 95760      송소은  female  31.0     NaN           146.0        136.0    False
# 37059      정승예  female  33.0   159.0           145.0        135.0    False
# 34914      허승희  female   NaN   172.0           144.0        134.0    False
# 68401      한수훈    male  39.0   169.0           144.0        134.0    False
# 7348       한시혁    male  30.0   174.0           143.0        133.0    False
# 22815      황수민  female  30.0   165.0           143.0        133.0    False
# 106408     이준우    male  37.0   174.0           142.0        132.0     True
# 34347      장윤일    male  32.0   183.0           141.0        131.0     True
# 104728     허찬호    male  33.0   182.0           141.0        131.0    False
# 31961      김지민  female  31.0   172.0           140.0        130.0    False
# 67457      허찬호    male  39.0     NaN           140.0        130.0     True
# 71591      임수훈    male  41.0     NaN           140.0        130.0    False
# 83626      김대훈    male  35.0   183.0           140.0        130.0    False
# 58400      안수진  female   NaN   162.0           139.0        129.0    False
# 1176       최도윤    male  32.0     NaN           138.0        128.0    False
# 30157      문윤준    male  24.0   175.0           138.0        128.0    False
# 34702      박세은  female  34.0   171.0           138.0        128.0     True
# 100665     전슬영  female  37.0   168.0           138.0        128.0    False
# 51596      고수정  female  28.0   168.0           137.0        127.0    False
# ...        ...     ...   ...     ...             ...          ...      ...
# 24947      배윤오    male  35.0   174.0            82.0         72.0    False
# 25296      정동운    male  42.0   177.0            82.0         72.0    False
# 25315      윤유현    male  39.0   181.0            82.0         72.0    False
# 25351      류준성    male  40.0   167.0            82.0         72.0    False
# 25357      장주호    male  37.0   182.0            82.0         72.0     True
# 25375      장윤후    male  38.0   177.0            82.0         72.0    False
# 26355      홍서진    male  33.0     NaN            82.0         72.0    False
# 26627      고준연    male  27.0   169.0            82.0         72.0    False
# 27129      문효찬    male  33.0   175.0            82.0         72.0    False
# 27365      양준아    male  23.0   171.0            82.0         72.0    False
# 27806      김도율    male  35.0   175.0            82.0         72.0    False
# 27869      박윤진    male  35.0     NaN            82.0         72.0    False
# 27903      장승우    male  27.0   169.0            82.0         72.0    False
# 27949      장시빈    male  29.0   174.0            82.0         72.0    False
# 28369      황윤진    male  29.0   174.0            82.0         72.0    False
# 28939      배윤일    male  25.0   171.0            82.0         72.0    False
# 28999      오동인    male  36.0   176.0            82.0         72.0    False
# 29235      류영인    male  35.0     NaN            82.0         72.0    False
# 29435      장태윤    male  46.0   177.0            82.0         72.0    False
# 29488   허지후,지혁    male  34.0   170.0            82.0         72.0    False
# 29684      윤도영    male  40.0   176.0            82.0         72.0     True
# 29848      정민진    male  30.0   174.0            82.0         72.0    False
# 29876      송도율    male  35.0   165.0            82.0         72.0    False
# 30035      최유상    male  43.0   171.0            82.0         72.0    False
# 30279      고지완    male  32.0   171.0            82.0         72.0     True
# 30610      홍원재    male   NaN     NaN            82.0         72.0    False
# 30771      백영찬    male   NaN   173.0            82.0         72.0    False
# 30810      허현준    male  30.0   167.0            82.0         72.0     True
# 31183      조영준    male  34.0   176.0            82.0         72.0    False
# 31317      허재훈    male  37.0   179.0            82.0         72.0    False
#
#         Drinking   Phone Number  Request Counselling  Paid Plan  Joined At  \
# 63964        1.0            NaN                False        NaN 2017-09-26
# 72421        8.0  010-7789-4522                False        NaN 2017-07-16
# 75204        NaN  010-8674-7196                False        3.0 2016-04-12
# 105948       2.0  010-1828-1982                False        3.0 2016-01-11
# 2650         1.0  010-4179-4763                False        NaN 2016-08-03
# 9295         2.0  010-1278-9392                False        NaN 2017-09-18
# 17178        2.0  010-6626-7714                False        NaN 2016-07-01
# 43658        1.0  010-4947-6767                False        NaN 2017-05-04
# 51678        2.0  010-2383-7169                False        NaN 2016-09-30
# 80402        NaN  010-2579-3335                False        NaN 2017-03-03
# 84371        NaN  010-2579-3335                False        NaN 2017-03-03
# 95760        8.0  010-5311-3885                False        NaN 2017-08-03
# 37059        4.0  010-3932-8139                False        6.0 2017-10-13
# 34914        1.0  010-3667-6516                False        3.0 2016-07-16
# 68401        4.0            NaN                False        6.0 2016-10-13
# 7348         NaN  010-5578-9572                False        NaN 2016-12-11
# 22815        2.0  010-1753-6781                False        NaN 2016-08-02
# 106408       2.0  010-6251-5168                False        NaN 2017-07-22
# 34347        2.0  010-9772-3532                False        NaN 2017-09-29
# 104728       1.0  010-1537-2346                False        NaN 2017-11-12
# 31961        NaN  010-3961-6926                False        NaN 2016-07-09
# 67457        8.0  010-9279-2583                False        NaN 2017-06-23
# 71591        4.0            NaN                False        6.0 2016-07-15
# 83626        2.0  010-3355-4726                False        3.0 2016-06-05
# 58400        4.0  010-1954-7185                False        3.0 2017-09-26
# 1176         1.0  010-6145-9866                False        NaN 2017-06-06
# 30157        4.0  010-9981-8269                False        NaN 2016-06-21
# 34702        1.0            NaN                False        NaN 2016-02-09
# 100665       4.0  010-2676-1997                False        NaN 2017-11-26
# 51596        4.0  010-7997-3261                False        6.0 2016-09-05
# ...          ...            ...                  ...        ...        ...
# 24947        2.0  010-9781-2633                False        3.0 2017-04-03
# 25296        NaN  010-7466-2474                False        NaN 2016-07-13
# 25315        4.0  010-7394-5446                False        6.0 2017-08-25
# 25351        NaN  010-5192-4682                False        NaN 2016-10-20
# 25357        8.0  010-8541-8398                False        3.0 2017-08-06
# 25375        4.0  010-6722-8869                False        NaN 2017-08-02
# 26355        2.0            NaN                False        3.0 2016-02-24
# 26627        8.0  010-3537-4248                False        NaN 2017-05-19
# 27129        4.0  010-9943-9463                False        NaN 2016-08-03
# 27365        4.0  010-8691-4492                False        NaN 2016-09-01
# 27806        2.0  010-7922-8859                False        NaN 2016-12-21
# 27869        NaN  010-3854-8437                False        NaN 2016-07-07
# 27903        2.0  010-6942-6365                False        NaN 2017-09-27
# 27949        1.0  010-6368-5957                False        NaN 2017-03-22
# 28369        NaN  010-6251-6536                False        NaN 2017-01-25
# 28939        4.0  010-3287-5926                False        6.0 2016-07-06
# 28999        4.0  010-9558-1732                False       12.0 2017-04-17
# 29235        2.0  010-1899-8778                False        NaN 2016-10-06
# 29435        4.0  010-1398-6789                False        NaN 2017-05-09
# 29488        8.0  010-3148-1773                False        NaN 2017-03-18
# 29684        1.0  010-6396-9228                False        NaN 2016-06-10
# 29848        4.0  010-2173-1649                False        3.0 2017-03-21
# 29876        8.0  010-7888-5633                False        3.0 2017-04-08
# 30035        4.0  010-8656-4765                False        3.0 2016-08-13
# 30279        2.0  010-8649-4997                False        NaN 2017-03-29
# 30610        1.0  010-8263-4161                False        NaN 2016-12-12
# 30771        4.0  010-6822-6385                False        NaN 2016-09-08
# 30810        1.0  010-3791-5823                False       12.0 2017-09-14
# 31183        4.0  010-6985-6818                False        NaN 2016-05-10
# 31317        2.0  010-3723-8899                False        3.0 2017-06-26
#
#        Updated At  Is Free  IsDrinking  Loss Goal       To Do    VIP
# 63964  2017-10-19     True         1.0       10.0      reject  False
# 72421  2017-08-19     True         1.0       10.0   confirmed  False
# 75204  2016-04-12    False         0.0       10.0   confirmed  False
# 105948 2016-01-11    False         1.0       10.0   confirmed  False
# 2650   2016-08-03     True         1.0       10.0   confirmed  False
# 9295   2017-11-21     True         1.0       10.0   confirmed  False
# 17178  2016-09-28     True         1.0       10.0   confirmed  False
# 43658  2017-05-04     True         1.0       10.0   confirmed  False
# 51678  2016-09-30     True         1.0       10.0   confirmed  False
# 80402  2017-03-03     True         0.0       10.0   confirmed  False
# 84371  2017-03-03     True         0.0       10.0  duplicated  False
# 95760  2017-08-03     True         1.0       10.0   confirmed  False
# 37059  2017-10-13    False         1.0       10.0   confirmed  False
# 34914  2016-10-12    False         1.0       10.0   confirmed  False
# 68401  2016-10-13    False         1.0       10.0  duplicated  False
# 7348   2016-12-11     True         0.0       10.0   confirmed  False
# 22815  2016-08-02     True         1.0       10.0   confirmed  False
# 106408 2017-07-22     True         1.0       10.0   confirmed  False
# 34347  2017-09-29     True         1.0       10.0   confirmed  False
# 104728 2017-11-12     True         1.0       10.0   confirmed  False
# 31961  2016-07-09     True         0.0       10.0   confirmed  False
# 67457  2017-06-23     True         1.0       10.0   confirmed  False
# 71591  2016-08-28    False         1.0       10.0  duplicated  False
# 83626  2016-06-05    False         1.0       10.0   confirmed  False
# 58400  2017-09-26    False         1.0       10.0   confirmed  False
# 1176   2017-06-06     True         1.0       10.0   confirmed  False
# 30157  2016-06-21     True         1.0       10.0   confirmed  False
# 34702  2016-02-09     True         1.0       10.0      reject  False
# 100665 2017-11-26     True         1.0       10.0   confirmed  False
# 51596  2016-09-05    False         1.0       10.0   confirmed  False
# ...           ...      ...         ...        ...         ...    ...
# 24947  2017-05-06    False         1.0       10.0   confirmed  False
# 25296  2016-07-13     True         0.0       10.0   confirmed  False
# 25315  2017-08-25    False         1.0       10.0   confirmed  False
# 25351  2016-10-20     True         0.0       10.0   confirmed  False
# 25357  2017-10-18    False         1.0       10.0   confirmed  False
# 25375  2017-08-02     True         1.0       10.0   confirmed  False
# 26355  2016-02-24    False         1.0       10.0  duplicated  False
# 26627  2017-08-09     True         1.0       10.0   confirmed  False
# 27129  2016-09-26     True         1.0       10.0   confirmed  False
# 27365  2016-09-01     True         1.0       10.0   confirmed  False
# 27806  2017-01-20     True         1.0       10.0   confirmed  False
# 27869  2016-09-18     True         0.0       10.0   confirmed  False
# 27903  2017-09-27     True         1.0       10.0   confirmed  False
# 27949  2017-05-06     True         1.0       10.0   confirmed  False
# 28369  2017-01-25     True         0.0       10.0   confirmed  False
# 28939  2016-07-06    False         1.0       10.0   confirmed  False
# 28999  2017-04-17    False         1.0       10.0   confirmed  False
# 29235  2016-10-06     True         1.0       10.0   confirmed  False
# 29435  2017-05-09     True         1.0       10.0   confirmed  False
# 29488  2017-03-22     True         1.0       10.0   confirmed  False
# 29684  2016-06-10     True         1.0       10.0   confirmed  False
# 29848  2017-03-21    False         1.0       10.0   confirmed  False
# 29876  2017-07-15    False         1.0       10.0   confirmed  False
# 30035  2016-08-13    False         1.0       10.0   confirmed  False
# 30279  2017-03-29     True         1.0       10.0   confirmed  False
# 30610  2016-12-12     True         1.0       10.0   confirmed  False
# 30771  2016-09-08     True         1.0       10.0   confirmed  False
# 30810  2017-09-14    False         1.0       10.0   confirmed  False
# 31183  2016-05-10     True         1.0       10.0   confirmed  False
# 31317  2017-06-26    False         1.0       10.0   confirmed  False
#
# [1000 rows x 18 columns]

# %%
vip_user = users[users['To Do'] != 'counselling'].nlargest(1000, ['Loss Goal', 'Current Weight'])

# %%
users.loc[vip_user.index, 'VIP'] = True

# %%
users[users['To Do'] != 'counselling'].nlargest(1000, ['Loss Goal', 'Current Weight'])
# Out:
#           Name  Gender   Age  Height  Current Weight  Goal Weight  Smoking  \
# 63964      임장훈    male  34.0   181.0           149.0        139.0    False
# 72421      장초은  female  35.0   168.0           149.0        139.0    False
# 75204      송수정  female  34.0   176.0           149.0        139.0    False
# 105948     최유준    male  30.0   176.0           149.0        139.0    False
# 2650       황재호    male  37.0   177.0           148.0        138.0    False
# 9295       조영후    male  29.0   180.0           147.0        137.0     True
# 17178      양인태    male  36.0   171.0           147.0        137.0    False
# 43658      송서준    male  25.0   175.0           147.0        137.0    False
# 51678      조시훈    male  33.0   177.0           147.0        137.0    False
# 80402      손동은    male  35.0   176.0           147.0        137.0     True
# 84371      손동은    male  35.0   176.0           147.0        137.0     True
# 95760      송소은  female  31.0     NaN           146.0        136.0    False
# 37059      정승예  female  33.0   159.0           145.0        135.0    False
# 34914      허승희  female   NaN   172.0           144.0        134.0    False
# 68401      한수훈    male  39.0   169.0           144.0        134.0    False
# 7348       한시혁    male  30.0   174.0           143.0        133.0    False
# 22815      황수민  female  30.0   165.0           143.0        133.0    False
# 106408     이준우    male  37.0   174.0           142.0        132.0     True
# 34347      장윤일    male  32.0   183.0           141.0        131.0     True
# 104728     허찬호    male  33.0   182.0           141.0        131.0    False
# 31961      김지민  female  31.0   172.0           140.0        130.0    False
# 67457      허찬호    male  39.0     NaN           140.0        130.0     True
# 71591      임수훈    male  41.0     NaN           140.0        130.0    False
# 83626      김대훈    male  35.0   183.0           140.0        130.0    False
# 58400      안수진  female   NaN   162.0           139.0        129.0    False
# 1176       최도윤    male  32.0     NaN           138.0        128.0    False
# 30157      문윤준    male  24.0   175.0           138.0        128.0    False
# 34702      박세은  female  34.0   171.0           138.0        128.0     True
# 100665     전슬영  female  37.0   168.0           138.0        128.0    False
# 51596      고수정  female  28.0   168.0           137.0        127.0    False
# ...        ...     ...   ...     ...             ...          ...      ...
# 24947      배윤오    male  35.0   174.0            82.0         72.0    False
# 25296      정동운    male  42.0   177.0            82.0         72.0    False
# 25315      윤유현    male  39.0   181.0            82.0         72.0    False
# 25351      류준성    male  40.0   167.0            82.0         72.0    False
# 25357      장주호    male  37.0   182.0            82.0         72.0     True
# 25375      장윤후    male  38.0   177.0            82.0         72.0    False
# 26355      홍서진    male  33.0     NaN            82.0         72.0    False
# 26627      고준연    male  27.0   169.0            82.0         72.0    False
# 27129      문효찬    male  33.0   175.0            82.0         72.0    False
# 27365      양준아    male  23.0   171.0            82.0         72.0    False
# 27806      김도율    male  35.0   175.0            82.0         72.0    False
# 27869      박윤진    male  35.0     NaN            82.0         72.0    False
# 27903      장승우    male  27.0   169.0            82.0         72.0    False
# 27949      장시빈    male  29.0   174.0            82.0         72.0    False
# 28369      황윤진    male  29.0   174.0            82.0         72.0    False
# 28939      배윤일    male  25.0   171.0            82.0         72.0    False
# 28999      오동인    male  36.0   176.0            82.0         72.0    False
# 29235      류영인    male  35.0     NaN            82.0         72.0    False
# 29435      장태윤    male  46.0   177.0            82.0         72.0    False
# 29488   허지후,지혁    male  34.0   170.0            82.0         72.0    False
# 29684      윤도영    male  40.0   176.0            82.0         72.0     True
# 29848      정민진    male  30.0   174.0            82.0         72.0    False
# 29876      송도율    male  35.0   165.0            82.0         72.0    False
# 30035      최유상    male  43.0   171.0            82.0         72.0    False
# 30279      고지완    male  32.0   171.0            82.0         72.0     True
# 30610      홍원재    male   NaN     NaN            82.0         72.0    False
# 30771      백영찬    male   NaN   173.0            82.0         72.0    False
# 30810      허현준    male  30.0   167.0            82.0         72.0     True
# 31183      조영준    male  34.0   176.0            82.0         72.0    False
# 31317      허재훈    male  37.0   179.0            82.0         72.0    False
#
#         Drinking   Phone Number  Request Counselling  Paid Plan  Joined At  \
# 63964        1.0            NaN                False        NaN 2017-09-26
# 72421        8.0  010-7789-4522                False        NaN 2017-07-16
# 75204        NaN  010-8674-7196                False        3.0 2016-04-12
# 105948       2.0  010-1828-1982                False        3.0 2016-01-11
# 2650         1.0  010-4179-4763                False        NaN 2016-08-03
# 9295         2.0  010-1278-9392                False        NaN 2017-09-18
# 17178        2.0  010-6626-7714                False        NaN 2016-07-01
# 43658        1.0  010-4947-6767                False        NaN 2017-05-04
# 51678        2.0  010-2383-7169                False        NaN 2016-09-30
# 80402        NaN  010-2579-3335                False        NaN 2017-03-03
# 84371        NaN  010-2579-3335                False        NaN 2017-03-03
# 95760        8.0  010-5311-3885                False        NaN 2017-08-03
# 37059        4.0  010-3932-8139                False        6.0 2017-10-13
# 34914        1.0  010-3667-6516                False        3.0 2016-07-16
# 68401        4.0            NaN                False        6.0 2016-10-13
# 7348         NaN  010-5578-9572                False        NaN 2016-12-11
# 22815        2.0  010-1753-6781                False        NaN 2016-08-02
# 106408       2.0  010-6251-5168                False        NaN 2017-07-22
# 34347        2.0  010-9772-3532                False        NaN 2017-09-29
# 104728       1.0  010-1537-2346                False        NaN 2017-11-12
# 31961        NaN  010-3961-6926                False        NaN 2016-07-09
# 67457        8.0  010-9279-2583                False        NaN 2017-06-23
# 71591        4.0            NaN                False        6.0 2016-07-15
# 83626        2.0  010-3355-4726                False        3.0 2016-06-05
# 58400        4.0  010-1954-7185                False        3.0 2017-09-26
# 1176         1.0  010-6145-9866                False        NaN 2017-06-06
# 30157        4.0  010-9981-8269                False        NaN 2016-06-21
# 34702        1.0            NaN                False        NaN 2016-02-09
# 100665       4.0  010-2676-1997                False        NaN 2017-11-26
# 51596        4.0  010-7997-3261                False        6.0 2016-09-05
# ...          ...            ...                  ...        ...        ...
# 24947        2.0  010-9781-2633                False        3.0 2017-04-03
# 25296        NaN  010-7466-2474                False        NaN 2016-07-13
# 25315        4.0  010-7394-5446                False        6.0 2017-08-25
# 25351        NaN  010-5192-4682                False        NaN 2016-10-20
# 25357        8.0  010-8541-8398                False        3.0 2017-08-06
# 25375        4.0  010-6722-8869                False        NaN 2017-08-02
# 26355        2.0            NaN                False        3.0 2016-02-24
# 26627        8.0  010-3537-4248                False        NaN 2017-05-19
# 27129        4.0  010-9943-9463                False        NaN 2016-08-03
# 27365        4.0  010-8691-4492                False        NaN 2016-09-01
# 27806        2.0  010-7922-8859                False        NaN 2016-12-21
# 27869        NaN  010-3854-8437                False        NaN 2016-07-07
# 27903        2.0  010-6942-6365                False        NaN 2017-09-27
# 27949        1.0  010-6368-5957                False        NaN 2017-03-22
# 28369        NaN  010-6251-6536                False        NaN 2017-01-25
# 28939        4.0  010-3287-5926                False        6.0 2016-07-06
# 28999        4.0  010-9558-1732                False       12.0 2017-04-17
# 29235        2.0  010-1899-8778                False        NaN 2016-10-06
# 29435        4.0  010-1398-6789                False        NaN 2017-05-09
# 29488        8.0  010-3148-1773                False        NaN 2017-03-18
# 29684        1.0  010-6396-9228                False        NaN 2016-06-10
# 29848        4.0  010-2173-1649                False        3.0 2017-03-21
# 29876        8.0  010-7888-5633                False        3.0 2017-04-08
# 30035        4.0  010-8656-4765                False        3.0 2016-08-13
# 30279        2.0  010-8649-4997                False        NaN 2017-03-29
# 30610        1.0  010-8263-4161                False        NaN 2016-12-12
# 30771        4.0  010-6822-6385                False        NaN 2016-09-08
# 30810        1.0  010-3791-5823                False       12.0 2017-09-14
# 31183        4.0  010-6985-6818                False        NaN 2016-05-10
# 31317        2.0  010-3723-8899                False        3.0 2017-06-26
#
#        Updated At  Is Free  IsDrinking  Loss Goal       To Do   VIP
# 63964  2017-10-19     True         1.0       10.0      reject  True
# 72421  2017-08-19     True         1.0       10.0   confirmed  True
# 75204  2016-04-12    False         0.0       10.0   confirmed  True
# 105948 2016-01-11    False         1.0       10.0   confirmed  True
# 2650   2016-08-03     True         1.0       10.0   confirmed  True
# 9295   2017-11-21     True         1.0       10.0   confirmed  True
# 17178  2016-09-28     True         1.0       10.0   confirmed  True
# 43658  2017-05-04     True         1.0       10.0   confirmed  True
# 51678  2016-09-30     True         1.0       10.0   confirmed  True
# 80402  2017-03-03     True         0.0       10.0   confirmed  True
# 84371  2017-03-03     True         0.0       10.0  duplicated  True
# 95760  2017-08-03     True         1.0       10.0   confirmed  True
# 37059  2017-10-13    False         1.0       10.0   confirmed  True
# 34914  2016-10-12    False         1.0       10.0   confirmed  True
# 68401  2016-10-13    False         1.0       10.0  duplicated  True
# 7348   2016-12-11     True         0.0       10.0   confirmed  True
# 22815  2016-08-02     True         1.0       10.0   confirmed  True
# 106408 2017-07-22     True         1.0       10.0   confirmed  True
# 34347  2017-09-29     True         1.0       10.0   confirmed  True
# 104728 2017-11-12     True         1.0       10.0   confirmed  True
# 31961  2016-07-09     True         0.0       10.0   confirmed  True
# 67457  2017-06-23     True         1.0       10.0   confirmed  True
# 71591  2016-08-28    False         1.0       10.0  duplicated  True
# 83626  2016-06-05    False         1.0       10.0   confirmed  True
# 58400  2017-09-26    False         1.0       10.0   confirmed  True
# 1176   2017-06-06     True         1.0       10.0   confirmed  True
# 30157  2016-06-21     True         1.0       10.0   confirmed  True
# 34702  2016-02-09     True         1.0       10.0      reject  True
# 100665 2017-11-26     True         1.0       10.0   confirmed  True
# 51596  2016-09-05    False         1.0       10.0   confirmed  True
# ...           ...      ...         ...        ...         ...   ...
# 24947  2017-05-06    False         1.0       10.0   confirmed  True
# 25296  2016-07-13     True         0.0       10.0   confirmed  True
# 25315  2017-08-25    False         1.0       10.0   confirmed  True
# 25351  2016-10-20     True         0.0       10.0   confirmed  True
# 25357  2017-10-18    False         1.0       10.0   confirmed  True
# 25375  2017-08-02     True         1.0       10.0   confirmed  True
# 26355  2016-02-24    False         1.0       10.0  duplicated  True
# 26627  2017-08-09     True         1.0       10.0   confirmed  True
# 27129  2016-09-26     True         1.0       10.0   confirmed  True
# 27365  2016-09-01     True         1.0       10.0   confirmed  True
# 27806  2017-01-20     True         1.0       10.0   confirmed  True
# 27869  2016-09-18     True         0.0       10.0   confirmed  True
# 27903  2017-09-27     True         1.0       10.0   confirmed  True
# 27949  2017-05-06     True         1.0       10.0   confirmed  True
# 28369  2017-01-25     True         0.0       10.0   confirmed  True
# 28939  2016-07-06    False         1.0       10.0   confirmed  True
# 28999  2017-04-17    False         1.0       10.0   confirmed  True
# 29235  2016-10-06     True         1.0       10.0   confirmed  True
# 29435  2017-05-09     True         1.0       10.0   confirmed  True
# 29488  2017-03-22     True         1.0       10.0   confirmed  True
# 29684  2016-06-10     True         1.0       10.0   confirmed  True
# 29848  2017-03-21    False         1.0       10.0   confirmed  True
# 29876  2017-07-15    False         1.0       10.0   confirmed  True
# 30035  2016-08-13    False         1.0       10.0   confirmed  True
# 30279  2017-03-29     True         1.0       10.0   confirmed  True
# 30610  2016-12-12     True         1.0       10.0   confirmed  True
# 30771  2016-09-08     True         1.0       10.0   confirmed  True
# 30810  2017-09-14    False         1.0       10.0   confirmed  True
# 31183  2016-05-10     True         1.0       10.0   confirmed  True
# 31317  2017-06-26    False         1.0       10.0   confirmed  True
#
# [1000 rows x 18 columns]

# %%
users[users['VIP']==True].shape
# Out:
# (11098, 18)

# %%
users.to_csv('./data/VIP_LIST.csv')
